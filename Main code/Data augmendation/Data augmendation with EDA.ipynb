# %% [markdown]
# 20k clean - 1k hate - 1k offensive
# 20k clean - 10k hate - 10k offensive

# %% [markdown]
# # Text augmentation using EDA techniques

# %%
# Change these arguments to fit with your own data / project

class Argument:
    input = "/content/data_label_2.csv"
    output = "/content/drive/MyDrive/new_dataset15.5/augmented_dataset_label_2_num8_0.15_wordnet.txt"
    num_aug = 8
    alpha = 0.15
args = Argument()

# %%
words = get_synonyms('mặt trời')
print(words)
# Out:
# ['Mặt Trời', 'thái dương', 'Thái dương']

# %%
# CODE augmetation: https://github.com/jasonwei20/eda_nlp

import random
from random import shuffle

random.seed(1)
import json


# stop words list
stop_words = []
with open("/content/vietnamese-stopwords.txt", "r") as f:
    stop_words = []
    for line in f:
        dd = line.strip('\n')
        stop_words.append(dd)

# cleaning up text
import re


def get_only_chars(line):
    # clean_line = ""

    # line = line.replace("’", "")
    # line = line.replace("'", "")
    # line = line.replace("-", " ") #replace hyphens with spaces
    # line = line.replace("\t", " ")
    # line = line.replace("\n", " ")
    # line = line.lower()

    # for char in line:
    #     if char in 'qwertyuiopasdfghjklzxcvbnm ':
    #         clean_line += char
    #     else:
    #         clean_line += ' '

    # clean_line = re.sub(' +',' ',clean_line) #delete extra spaces
    # if clean_line[0] == ' ':
    #     clean_line = clean_line[1:]
    # return clean_line
    return line


########################################################################
# Synonym replacement
# Replace n words in the sentence with synonyms from wordnet
########################################################################

# for the first time you use wordnet
# import nltk
# nltk.download('wordnet')
from nltk.corpus import wordnet


def synonym_replacement(words, n):
    new_words = words.copy()
    random_word_list = list(set([word for word in words if word not in stop_words]))
    random.shuffle(random_word_list)
    num_replaced = 0
    for random_word in random_word_list:
        synonyms = get_synonyms(random_word)
        if len(synonyms) >= 1:
            synonym = random.choice(list(synonyms))
            new_words = [synonym if word == random_word else word for word in new_words]
            print("replaced", random_word, "with", synonym)
            num_replaced += 1
        if num_replaced >= n:  # only replace up to n words
            break

    # this is stupid but we need it, trust me
    sentence = ' '.join(new_words)
    new_words = sentence.split(' ')

    return new_words


# def get_synonyms(word):
# 	synonyms = set()
# 	for syn in wordnet.synsets(word):
# 		for l in syn.lemmas():
# 			synonym = l.name().replace("_", " ").replace("-", " ").lower()
# 			synonym = "".join([char for char in synonym if char in ' qwertyuiopasdfghjklzxcvbnm'])
# 			synonyms.add(synonym)
# 	if word in synonyms:
# 		synonyms.remove(word)
# 	return list(synonyms)

def get_synonyms(word):
    synonyms = set()
    with open("/content/word_net_vi.json", "r") as f:
        wordnet = json.load(f)

    for key, value in wordnet.items():
        if key.strip() == word:
            for v in value:
                synonyms.add(v.strip())

        if word in synonyms:
            synonyms.remove(word)
    return list(synonyms)


########################################################################
# Random deletion
# Randomly delete words from the sentence with probability p
########################################################################

def random_deletion(words, p):
    # obviously, if there's only one word, don't delete it
    if len(words) == 1:
        return words

    # randomly delete words with probability p
    new_words = []
    for word in words:
        r = random.uniform(0, 1)
        if r > p:
            new_words.append(word)

    # if you end up deleting all words, just return a random word
    if len(new_words) == 0:
        rand_int = random.randint(0, len(words) - 1)
        return [words[rand_int]]

    return new_words


########################################################################
# Random swap
# Randomly swap two words in the sentence n times
########################################################################

def random_swap(words, n):
    new_words = words.copy()
    for _ in range(n):
        if len(new_words) > 0:
            new_words = swap_word(new_words)
    return new_words


def swap_word(new_words):
    random_idx_1 = random.randint(0, len(new_words) - 1)
    random_idx_2 = random_idx_1
    counter = 0
    while random_idx_2 == random_idx_1:
        random_idx_2 = random.randint(0, len(new_words) - 1)
        counter += 1
        if counter > 3:
            return new_words
    new_words[random_idx_1], new_words[random_idx_2] = new_words[random_idx_2], new_words[random_idx_1]
    return new_words


########################################################################
# Random insertion
# Randomly insert n words into the sentence
########################################################################

def random_insertion(words, n):
    new_words = words.copy()
    for _ in range(n):
        add_word(new_words)
    return new_words


def add_word(new_words):
    synonyms = []
    counter = 0
    while len(synonyms) < 1 and len(new_words) > 0:
    # while len(synonyms) < 1:
        random_word = new_words[random.randint(0, len(new_words) - 1)]
        synonyms = get_synonyms(random_word)
        counter += 1
        if counter >= 10:
            return

    if len(new_words) > 0:
        random_synonym = synonyms[0]
        random_idx = random.randint(0, len(new_words) - 1)
        new_words.insert(random_idx, random_synonym)


########################################################################
# main data augmentation function
########################################################################

def eda(sentence, alpha_sr=0.1, alpha_ri=0.1, alpha_rs=0.1, p_rd=0.1, num_aug=9):
    sentence = get_only_chars(sentence)
    words = sentence.split(' ')
    words = [word for word in words if word != '']
    num_words = len(words)

    augmented_sentences = []

    if len(words) <= 0:
        return augmented_sentences
    num_new_per_technique = int(num_aug / 4) + 1
    n_sr = max(1, int(alpha_sr * num_words))
    n_ri = max(1, int(alpha_ri * num_words))
    n_rs = max(1, int(alpha_rs * num_words))

    # sr
    for _ in range(num_new_per_technique):
        a_words = synonym_replacement(words, n_sr)
        augmented_sentences.append(' '.join(a_words))

    # ri
    for _ in range(num_new_per_technique):
        a_words = random_insertion(words, n_ri)
        augmented_sentences.append(' '.join(a_words))

    # rs
    for _ in range(num_new_per_technique):
        a_words = random_swap(words, n_rs)
        augmented_sentences.append(' '.join(a_words))

    # rd
    for _ in range(num_new_per_technique):
        a_words = random_deletion(words, p_rd)
        augmented_sentences.append(' '.join(a_words))

    augmented_sentences = list(set(augmented_sentences))
    augmented_sentences = [get_only_chars(sentence) for sentence in augmented_sentences]
    shuffle(augmented_sentences)

    # trim so that we have the desired number of augmented sentences
    if num_aug >= 1:
        augmented_sentences = augmented_sentences[:num_aug]
    else:
        keep_prob = num_aug / len(augmented_sentences)
        augmented_sentences = [s for s in augmented_sentences if random.uniform(0, 1) < keep_prob]

    # append the original sentence
    #augmented_sentences.append(sentence)

    return augmented_sentences


# the output file
output = None
if args.output:
    output = args.output
else:
    from os.path import dirname, basename, join

    output = join(dirname(args.input), 'eda_' + basename(args.input))

# number of augmented sentences to generate per original sentence
num_aug = 9  # default
if args.num_aug:
    num_aug = args.num_aug

# how much to change each sentence
alpha = 0.1  # default
if args.alpha:
    alpha = args.alpha


# generate more data with standard augmentation
def gen_eda(train_orig, output_file, alpha, num_aug=9):
    try:
        writer = open(output_file, 'w')
        lines = open(train_orig, 'r').readlines()

        writer.write("free_text" + "," + "label_id" + '\n')
        augm = ""
        for i, line in enumerate(lines):
            try:
                parts = line[:-1].split('|')
                # print(parts)
                # sen_id = parts[0]
                label = parts[1]
                sentence = parts[0]
                aug_sentences = eda(sentence, alpha_sr=alpha, alpha_ri=alpha, alpha_rs=alpha, p_rd=alpha, num_aug=num_aug)
                for aug_sentence in aug_sentences:
                    # writer.write(label + "\t" + aug_sentence + '\n')
                    # writer.write(sen_id + "," +aug_sentence + "," + label + '\n')
                    augm = augm + aug_sentence + "," + label + '\n'
            except Exception as e:
                print(e)
                print(parts)
                pass

        writer.write(augm)
        writer.close()
        print(
            "generated augmented sentences with eda for " + train_orig + " to " + output_file + " with num_aug=" + str(
                num_aug))
    except Exception as e:
        raise e
        pass

# %% [markdown]
# ## Main code. Run the cell below to generate new texts

# %%
# main function. Run this cell to generate new data
if __name__ == "__main__":
    # generate augmented sentences and output into a new file
    gen_eda(args.input, args.output, alpha=alpha, num_aug=num_aug)
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# replaced lề with nghi tiết
# replaced thằng with gã
# replaced cộng with gộp
# replaced lề with nghi thức
# replaced cộng with lấy tổng
# replaced lề with lề thói
# replaced cai with cai rượu
# replaced cai with cai rượu
# replaced bi with bi thuốc
# replaced chua with lên men
# replaced quan with quan lại
# replaced tham with dã tâm
# replaced vay with vay mượn
# replaced am with thất
# replaced phai with loang ra
# replaced y with y khoa
# replaced bao with quây quanh
# replaced hai with II
# replaced da with da động vật
# replaced chua with lên men
# replaced vay with vay mượn
# replaced ong with đàn ong
# replaced cai with cai nghiện
# replaced hai with đôi
# replaced am with thất
# replaced tham with hoài bão
# replaced quan with quan lại
# replaced bao with bao quanh
# replaced xoa with láng
# replaced bao with bao quanh
# replaced da with da động vật
# replaced am with thất
# replaced moi with cố lấy được
# replaced co with rút
# replaced tham with dã tâm
# replaced chua with bị hẩu
# replaced phai with loang ra
# replaced xoa with làm mịn
# replaced y with y học
# replaced Trung with sông Trung
# replaced Trung with sông Trung
# replaced Trung with sông Trung
# replaced tiếp with vạch biên giới
# replaced bố with bốc hơi
# replaced bố with bốc hơi
# replaced đi with đi tù
# replaced bố with bốc hơi
# replaced đi with nằm
# replaced sai with không phải
# replaced chê with phê phán
# replaced thấu with xuyên thấu
# replaced mê with yêu tha thiết
# replaced phân with đứng giữa
# replaced bọn with đoàn
# replaced tầm with cấp
# replaced chê with trách
# replaced đần with ngu dốt
# replaced mê with yêu tha thiết
# replaced thấu with thấm vào
# replaced phân with phân chia
# replaced bọn with giới
# replaced chê with chỉ trích
# replaced phân with đứng giữa
# replaced khen with tuyên dương
# replaced ngu with sự tối tăm
# replaced sai with bất công
# replaced gánh with gánh chịu
# replaced gánh with chịu
# replaced gánh with gánh chịu
# replaced vực with vực thẳm
# replaced mặt with mặt trên
# replaced chỗ with suất
# replaced đòi with yêu cầu
# replaced đi with ngồi tù
# replaced vực with vực thẳm
# replaced hàng with quy hàng
# replaced đi with ngồi bóc lịch
# replaced kê with đệm
# replaced hồ with hồ cứng
# replaced chỗ with chỗ trống
# replaced mặt with mặt trên
# replaced vực with vực thẳm
# replaced kê with chặn
# replaced đòi with đòi hỏi
# replaced ngu with vô minh
# replaced ngu with sự vô minh
# replaced ngu with vô minh
# replaced bày with triển lãm
# replaced oi with oi ả
# replaced bày with trưng bầy
# replaced gánh with hứng
# replaced gánh with hứng
# replaced gánh with hứng
# replaced quang with quang đãng
# replaced ngu with dốt
# replaced mặt with mặt trên
# replaced độc with độc hại
# replaced hợm with kinh khỉnh
# replaced ghế with chỗ ngồi
# replaced đảng with phái
# replaced sách with quyển sách
# replaced vĩ with cây vĩ
# replaced dạy with dạy học
# replaced tượng with quân tượng
# replaced kiêu with kiêu ngạo
# replaced mặt with mặt trên
# replaced quang with quang đãng
# replaced viết with ghi
# replaced chế with chế tạo
# replaced hợm with hợm mình
# replaced ghế with chỗ ngồi
# replaced ngu with tối tăm
# replaced bốc with phun
# replaced tượng with con tượng
# replaced kiêu with kiêu hãnh
# replaced độc with độc hại
# replaced vĩ with cây vĩ
# replaced sách with quyển sách
# replaced cháy with rực sáng
# replaced quang with quang đãng
# replaced tượng with quân tượng
# replaced đảng with đảng phái
# replaced hợm with hợm hĩnh
# replaced bốc with bốc khói
# replaced viết with viết chính tả
# replaced độc with không lành
# replaced chế with chế tạo
# replaced ngu with sự mu muội
# replaced ghế with chỗ ngồi
# replaced ngu with tối tăm
# replaced giỏi with có khả năng
# replaced ngu with sự mu muội
# replaced bắt with bắt phải chịu đựng
# replaced bắt with bắt phải chịu đựng
# replaced bắt with bắt phải chịu
# replaced tro with gio
# replaced khung with xương
# replaced khung with xương
# replaced Trần with triều đại Trần
# replaced Trần with triều nhà Trần
# replaced Trần with triều nhà Trần
# replaced gái with ca ve
# replaced xấu with độc địa
# replaced gái with gái mại dâm
# replaced cá with cược
# replaced cụ with vị
# replaced cụ with vị
# replaced cá with cá cược
# replaced cụ with vị
# replaced cá with đánh cuộc
# replaced ác with độc ác
# replaced giúp with cứu giúp
# replaced diệt with tận diệt
# replaced quân with quân bài
# replaced thổ with đất
# replaced quân with quân bài
# replaced ngờ with hồ nghi
# replaced diệt with diệt trừ
# replaced ác with ác độc
# replaced quân with quân bài
# replaced giúp with giúp ích
# replaced ngờ with sự nghi ngờ
# replaced dám with mạo phạm
# replaced dám with mạo phạm
# replaced dám with mạo muội
# replaced khúc with khúc gỗ mới xẻ
# replaced chủ with người chủ
# replaced thành with là
# replaced bếp with lò
# replaced bẻ with bẻ gẫy
# replaced bẻ with bẻ gẫy
# replaced thành with là
# replaced bếp with lò
# replaced né with tránh
# replaced phó with cấp phó
# replaced đường with đường đi
# replaced né with né tránh
# replaced phó with cấp phó
# replaced khúc with khúc gỗ
# replaced chủ with chủ lao động
# replaced cắn with ngoạm
# replaced nhốt with giam
# replaced cắn with đớp
# replaced nhốt with giam
# replaced cắn with ngoạm
# replaced nhốt with giam
# replaced báo with thông báo
# replaced tiêu with chi tiêu
# replaced ninh with hầm
# replaced diệt with tận diệt
# replaced báo with bảo cho biết
# replaced tình with tình cảm
# replaced bọn with đám
# replaced rách with thủng
# replaced ngu with sự vô minh
# replaced ngu with sự ngu xi
# replaced rách with thủng
# replaced yêu with thương
# replaced bọn with lũ
# replaced ngu with sự tối tăm
# replaced rách with thủng
# replaced dái with bìu dái
# replaced dái with bìu dái
# replaced dái with bìu dái
# replaced đảo with đảo kính
# replaced đa with nhiều
# replaced lừa with lừa phỉnh
# replaced đảo with đảo kính
# replaced đa with nhiều
# replaced lừa with lừa bịp
# replaced soi with kiểm tra
# replaced nghèo with nghèo nàn
# replaced kích with cái kích
# replaced than with kêu ca
# replaced xả with dùng cạn sạch
# replaced báo with bảo
# replaced súng with cây hoa súng
# replaced xả with dùng hết
# replaced kích with cái kích
# replaced báo with cho biết
# replaced soi with kiểm tra
# replaced động with hanh lớn
# replaced báo with bảo cho biết
# replaced động with hanh lớn
# replaced kích with cái kích
# replaced nghèo with nghèo túng
# replaced soi with kiểm tra
# replaced xả with làm cạn sạch
# replaced màng with màng bọc
# replaced muộn with trễ
# replaced gốm with sành sứ
# replaced mắc with kẹp
# replaced mắc with kẹp
# replaced mắc with vướng
# replaced ngu with sự mu muội
# replaced ngu with sự ngu muội
# replaced ngu with sự vô minh
# replaced tục with lệ
# replaced tục with lệ
# replaced tục with lệ
# replaced Trung with sông Trung
# replaced thần with vị thần
# replaced Trung with sông Trung
# replaced kỉ with kỉ địa chất
# replaced sinh with tới từ
# replaced kỉ with kỷ địa chất
# replaced sinh with tới từ
# replaced kỉ with kỷ địa chất
# replaced sinh with quê quán ở
# replaced thầy with người thầy
# replaced thầy with giáo viên
# replaced thầy with người giáo viên
# replaced lo with bảo đảm
# replaced cứt with phân
# replaced cứt with phân
# replaced lo with đảm đương
# replaced cộng with cộng gộp
# replaced lo with chịu trách nhiệm
# replaced chân with chân nền
# replaced chân with phần đáy
# replaced chân with nền
# replaced mẹ with sinh vật mẹ
# replaced luật with bộ luật
# replaced luật with bộ luật
# replaced ngột with khó thở
# replaced chết with hi sinh
# replaced chết with ngã xuống
# replaced no with trạng thái no nê
# replaced no with trạng thái no nê
# replaced no with trạng thái no nê
# replaced pha with hoà trộn
# replaced xếp with phân loại
# replaced mặt with mặt trên cùng
# replaced pha with trộn
# replaced tráng with tráng men
# replaced pha with trộn lẫn
# replaced gương with chiếc gương
# replaced tha with giải phóng
# replaced tha with thả
# replaced gương with chiếc gương
# replaced tha with giải thoát
# replaced gương with chiếc gương
# replaced cờ with trò chơi cờ
# replaced cờ with trò chơi cờ
# replaced cờ with trò chơi cờ
# replaced mặc with để mặc
# replaced tiếp with vạch đường biên giới
# replaced đi with bóc lịch
# replaced sử with lịch sử
# replaced hạ with chìm
# replaced chửi with chửi rủa
# replaced dừng with dừng lại
# replaced miệng with cửa
# replaced đi with đi tù
# replaced chửi with chửi rủa
# replaced tiếp with vạch đường biên giới
# replaced mặc with để mặc
# replaced tục with lệ
# replaced sử with lịch sử
# replaced hạ with lặn
# replaced miệng with cửa
# replaced mặc with để mặc
# replaced sử with sử kí
# replaced dừng with ngừng
# replaced tiếp with tiếp giáp với
# replaced đi with dựa cột
# replaced tục with lệ
# replaced miệng with cửa
# replaced chửi with chửi rủa
# replaced quan with quan lại
# replaced quan with quan lại
# replaced quan with quan lại
# replaced len with len lỏi
# replaced len with lách
# replaced len with len lỏi
# replaced điên with bị thần kinh
# replaced điên with bị tâm thần
# replaced điên with bị điên
# replaced giàu with giàu có
# replaced đi with nằm
# replaced dịch with được phiên dịch
# replaced đĩ with gái điếm
# replaced sát with bóc vỏ
# replaced giàu with dư dật
# replaced đĩ with kĩ nữ
# replaced đi with ngồi
# replaced đĩ with gái giang hồ
# replaced giàu with phong phú
# replaced đi with bóc lịch
# replaced sát with bóc vỏ
# replaced chờ with chờ đợi
# replaced chờ with chờ đợi
# replaced chờ with đợi chờ
# replaced giọng with tiếng
# replaced hát with ca hát
# replaced giọng with tiếng
# replaced phủ with bao phủ
# replaced nhiễu with nhiễu loạn
# replaced chạy with kéo dài
# replaced ô with ngăn
# replaced lộ with phơi bày
# replaced xác with thi hài
# replaced tham with tham vọng
# replaced nhiễu with nhiễu loạn
# replaced tham with tham lam
# replaced chạy with mở rộng
# replaced công with công cơ học
# replaced phủ with bao xung quanh
# replaced xác with xác người
# replaced lộ with phát hiện
# replaced lộ with khám phá
# replaced hối with hối hận
# replaced ô with ngăn
# replaced phủ with bao phủ
# replaced nhiễu with nhiễu loạn
# replaced chạy with kéo dài
# replaced tham with hoài bão
# replaced đi with nằm tù
# replaced mẹ with sinh vật mẹ
# replaced nghĩa with cái được biểu đạt
# replaced bò with trườn
# replaced đĩ with gái giang hồ
# replaced trâu with trâu nước
# replaced mẹ with sinh vật mẹ
# replaced nghĩa with cái được biểu đạt
# replaced đĩ with gái điếm
# replaced trâu with trâu sông
# replaced bò with trườn
# replaced đi with đi tù
# replaced mẹ with sinh vật mẹ
# replaced trâu with trâu sông
# replaced bò with bò trườn
# replaced nghĩa with cái được biểu đạt
# replaced đi with ngồi tù
# replaced đĩ with gái
# replaced đầu with thứ nhất
# replaced đầu with số 1
# replaced não with đầu
# replaced tức with bực tức
# replaced chua with bị chua
# replaced doi with eo đất
# replaced miệng with cửa
# replaced tức with bực tức
# replaced doi with dải đất
# replaced lai with lai giống
# replaced miệng with cửa
# replaced tức with bực tức
# replaced đạo with trộm ý tưởng
# replaced giả with không thật
# replaced đi with nằm
# replaced vật with đấu vật
# replaced thời with lúc
# replaced lưu with lưu lại
# replaced vật with vật nhau
# replaced tổ with ổ
# replaced đạo with ăn cắp ý tưởng
# replaced lưu with lưu lại
# replaced giả with không tự nhiên
# replaced đi with ngồi tù
# replaced thời with thời kỳ
# replaced tổ with ổ
# replaced giả with không tự nhiên
# replaced đạo with ăn cắp ý tưởng
# replaced đi with bóc lịch
# replaced lưu with vẫn còn
# replaced chôn with an táng
# replaced chôn with chôn cất
# replaced chôn with an táng
# replaced sủa with cắn
# replaced lâm with sa
# replaced lâm with rơi
# replaced sủa with cắn
# replaced lâm with rơi
# replaced sủa with cắn
# replaced điên with bị điên
# replaced điên with tâm thần
# replaced điên with bị tâm thần
# replaced cầu with cầu nguyện
# replaced da with da động vật
# replaced xong with xong xuôi
# replaced độc with hại
# replaced khéo with tinh xảo
# replaced coi with trông
# replaced cầu with khẩn cầu
# replaced nạn with hoạ
# replaced lũ with lụt
# replaced khéo with tinh vi
# replaced vui with thích thú
# replaced da with da động vật
# replaced độc with không tốt
# replaced xong with chấm dứt
# replaced hỏng with thất bại
# replaced đời with cuộc sống
# replaced dạy with dạy học
# replaced đời with cuộc sống
# replaced ca with phiên làm việc
# replaced ca with phiên
# replaced ca with phiên
# replaced túi with túi xách
# replaced đóng with khép
# replaced rút with đoạn tuyệt
# replaced rút with loại
# replaced túi with túi xách
# replaced tiếp with tiếp giáp với
# replaced rút with loại
# replaced túi with túi xách
# replaced quỹ with tiền quỹ
# replaced nghìn with 1.000
# replaced lượt with hiệp
# replaced bố with bốc hơi
# replaced đường with đường đi
# replaced coi with coi thi
# replaced trang with giai đoạn
# replaced công with công cơ học
# replaced lập with tạo lập
# replaced công with công cơ học
# replaced lập with thành lập
# replaced nghìn with ngàn
# replaced coi with coi thi
# replaced trang with giai đoạn
# replaced bố with bốc hơi
# replaced lượt with hiệp
# replaced đường with đường chuyển động
# replaced đường with đường chuyển động
# replaced coi with trông thi
# replaced lập with tạo lập
# replaced bố with bốc hơi
# replaced trang with giai đoạn
# replaced lượt with hiệp
# replaced nghìn with một ngàn
# replaced công with công cơ học
# replaced tã with tã lót
# replaced Trần with triều nhà Trần
# replaced xây with làm
# replaced tã with bỉm
# replaced chê with lên án
# replaced tã with bỉm
# replaced chọc with trêu tức
# replaced chút with ít
# replaced chửi with chửi rủa
# replaced bắt with bắt phải chịu
# replaced nhét with nhồi
# replaced chút with in ít
# replaced đầu with thứ nhất
# replaced chửi with chửi rủa
# replaced chọc with trêu
# replaced bắt with bắt phải chịu đựng
# replaced chút with chun chút
# replaced nhét with nhồi nhét
# replaced chọc with trêu tức
# replaced đầu with đầu tiên
# replaced thực with thật
# replaced ngân with hét
# replaced gửi with gởi gắm
# replaced hàng with khuất phục
# replaced đạo with ăn cắp
# replaced hàng with chịu thua
# replaced đạo with ăn cắp ý
# replaced gửi with gởi gắm
# replaced ngân with vang rền
# replaced gửi with kí thác
# replaced ngân with rú
# replaced hàng with quy phục
# replaced đạo with ăn cắp
# replaced chí with điểm chí
# replaced mẹ with sinh vật mẹ
# replaced đẻ with đẻ trứng
# replaced bày with trưng bầy
# replaced học with học bài
# replaced khinh with miệt thị
# replaced củ with thân củ
# replaced báo with bảo cho biết
# replaced học with học bài
# replaced củ with thân củ
# replaced báo with báo cho biết
# replaced khinh with miệt thị
# replaced đẻ with đẻ trứng
# replaced mẹ with sinh vật mẹ
# replaced bày with trưng bày
# replaced chí with điểm chí
# replaced đẻ with đẻ trứng
# replaced báo with cho biết
# replaced bày with triển lãm
# replaced củ with thân củ
# replaced học with học bài
# replaced chí with điểm chí
# replaced mẹ with sinh vật mẹ
# replaced khinh with miệt thị
# replaced học with học bài
# replaced Trung with sông Trung
# replaced Trung with sông Trung
# replaced động with hanh lớn
# replaced thuê with mướn
# replaced thuê with thuê mướn
# replaced động with hanh lớn
# replaced động with hanh lớn
# replaced thuê with mướn
# replaced mẹ with sinh vật mẹ
# replaced nạn with tai hoạ
# replaced hứa with hứa hẹn
# replaced thực with đúng sự thật
# replaced tham with tham vọng
# replaced tế with tế lễ
# replaced nạn with tai hoạ
# replaced thực with đúng sự thực
# replaced tham with tham lam
# replaced tế with hiến tế
# replaced mẹ with sinh vật mẹ
# replaced hứa with cam kết
# replaced nạn with tai hoạ
# replaced thực with đúng sự thật
# replaced tế with tế thần
# replaced hứa with hứa hẹn
# replaced mẹ with sinh vật mẹ
# replaced tham with hoài bão
# replaced gọi with chào gọi
# replaced chiến with chiếm đoạt
# replaced chiến with đóng giữ
# replaced bắt with bắt phải chịu đựng
# replaced đầu with số 1
# replaced kêu with vang lên
# replaced bò with bò trườn
# replaced độc with độc hại
# replaced tục with tục lệ
# replaced cầu with cầu nguyện
# replaced tục with lệ
# replaced chống with phản đối
# replaced tài with điêu luyện
# replaced cầu with nguyện cầu
# replaced tục with tục lệ
# replaced chống with chống đối
# replaced cầu with nguyện cầu
# replaced chửi with chửi rủa
# replaced sản with khoa phụ sản
# replaced sản with khoa phụ sản
# replaced sản with sản khoa
# replaced bay with bốc
# replaced bay with bốc
# replaced bay with bay lên
# replaced vãi with để rơi ra
# replaced ngu with dốt
# replaced ngu with sự mu muội
# replaced Ô with Lý
# replaced tiên with thần tiên
# replaced dịch with được phiên dịch
# replaced tiên with thần tiên
# replaced Ô with Ô châu
# replaced chết with ngã xuống
# replaced lo with chăm lo
# replaced lo with phụ trách
# replaced lo with chăm lo
# replaced đi with ngồi bóc lịch
# replaced đi with bóc lịch
# replaced đi with ngồi
# replaced đau with bị đau
# replaced đau with bị đau
# replaced đau with bị đau
# replaced đàn with tốp
# replaced đàn with bầy
# replaced đàn with tốp
# replaced chết with tử mạng
# replaced cụ with vị
# replaced giao with phân
# replaced cầm with nắm
# replaced ngờ with hồ nghi
# replaced thằng with gã
# replaced đạo with ăn cắp
# replaced cụ with vị
# replaced đi with ngồi bóc lịch
# replaced đập with co bóp
# replaced đường with đường đi
# replaced cầm with nắm
# replaced chửi with chửi rủa
# replaced ngờ with sự nghi hoặc
# replaced gậy with gạy
# replaced đập with co bóp
# replaced chết with tử mạng
# replaced giao with uỷ quyền
# replaced đi with nằm tù
# replaced sắt with Fe
# replaced cụ with vị
# replaced định with vạch
# replaced thằng with lão
# replaced chuỗi with loạt
# replaced đường with đường đi
# replaced biên with đường biên
# replaced đường with đường chuyển động
# replaced chuỗi with xâu
# replaced quy with bắt phải chịu
# replaced biên with đường biên giới
# replaced định with chỉ rõ
# replaced tất with bít tất
# replaced quy with bắt phải chịu
# replaced định with xác định
# replaced đường with đường đi
# replaced chuỗi with dòng
# replaced đi with đi tù
# replaced co with rút ngắn
# replaced đi with dựa cột
# replaced thi with kiểm tra
# replaced co with rút
# replaced chết with bỏ mạng
# replaced não with đầu
# replaced đi with ngồi
# replaced Nguyễn with nhà Nguyễn
# replaced bao with bao quanh
# replaced đi with dựa cột
# replaced bao with quây quanh
# replaced não with đầu óc
# replaced bọn with lũ
# replaced Nguyễn with nhà Nguyễn
# replaced não with đầu óc
# replaced bọn with lũ
# replaced đi with dựa cột
# replaced chửi with chửi rủa
# replaced thằng with gã
# replaced não with đầu óc
# replaced chửi with chửi rủa
# replaced thằng with gã
# replaced mặt with mặt trên cùng
# replaced chửi with chửi rủa
# replaced thằng with lão
# replaced mặt with mặt trên cùng
# replaced chậm with hiểu chậm
# replaced chậm with hiểu chậm
# replaced chậm with tiếp thu kém
# replaced cực with chiều phân cực
# replaced kì with cọ
# replaced cực with chiều phân cực
# replaced kì with kỳ
# replaced cực with chiều phân cực
# replaced kì with cọ
# replaced song with khung lưới
# replaced nhổ with dỡ
# replaced voi with con voi
# replaced Nguyễn with triều nhà Nguyễn
# replaced chi with tiêu
# replaced cứt with phân
# replaced sản with khoa sản
# replaced bọn with đoàn
# replaced mã with ám số
# replaced nhuộm with nhuộm sợi
# replaced phá with chống cự lại
# replaced chết with tử trận
# replaced mảnh with mảnh cắt
# replaced tiếp with vạch biên giới
# replaced chôn with chôn cất
# replaced bao with quây quanh
# replaced chôn with an táng
# replaced nhuộm with nhuộm sợi
# replaced tiên with thần tiên
# replaced trung with giống trung
# replaced đổ with bỏ
# replaced mã with ám tự
# replaced bao with bao quanh
# replaced tham with hoài bão
# replaced tiếp with giáp với
# replaced bọn with giới
# replaced cộng with tính tổng
# replaced máu with huyết
# replaced chôn with an táng
# replaced xác with thây người
# replaced bao with quây quanh
# replaced trung with giống trung
# replaced xương with khung xương
# replaced đáy with mặt đáy
# replaced đổ with quăng
# replaced tham with hoài bão
# replaced trốn with bỏ việc
# replaced ghen with ghen tuông
# replaced giàu with phong phú
# replaced giàu with phong phú
# replaced ghen with ghen tuông
# replaced công with công cơ học
# replaced giàu with dư dật
# replaced trốn with tự ý bỏ học
# replaced ghen with ghen tuông
# replaced chết with tử mạng
# replaced chết with hi sinh
# replaced chết with thiệt mạng
# replaced trái with trái ngược
# replaced sầu with rầu rĩ
# replaced trái with nghịch
# replaced ỉa with đi ỉa
# replaced kêu with vang
# replaced hát with ca hát
# replaced thằng with gã
# replaced chém with phăng
# replaced xả with dùng cạn sạch
# replaced kiểu with biện pháp
# replaced suốt with liên tục
# replaced hãm with làm chậm
# replaced phép with nguyên tắc
# replaced kẹt with mắc kẹt
# replaced hãm with làm chậm
# replaced toán with toán học
# replaced thèm with thèm khát
# replaced chặt with đẽo
# replaced bo with tip cho
# replaced chém with bổ
# replaced hát with ca
# replaced bo with boa cho
# replaced kêu with vang
# replaced toán with toán học
# replaced động with hanh lớn
# replaced kiểu with phương pháp
# replaced suốt with liên tục
# replaced ỉa with đi đồng
# replaced thèm with khát khao
# replaced dạy with dạy học
# replaced tham with tham vọng
# replaced quan with quan lại
# replaced tham with tham vọng
# replaced động with hanh lớn
# replaced động with hanh lớn
# replaced bọn with đám
# replaced lưu with lưu lại
# replaced sủa with cắn
# replaced đi with nằm tù
# replaced tởm with làm cho người ta không ưa
# replaced tởm with làm kinh tởm
# replaced tởm with kinh tởm
# replaced méo with bị trượt phá
# replaced đụng with va chạm nhau
# replaced đá with đạp
# replaced mặt with mặt trên
# replaced kiểu with cách thức
# replaced nổi with dập dềnh
# replaced rảnh with rỗi rãi
# replaced kiếm with xoay
# replaced hãm with làm chậm
# replaced kéo with kéo lê
# replaced móc with moi
# replaced hại with gây hại
# replaced hàng with khuất phục
# replaced tiếng with ngôn ngữ
# replaced não with óc
# replaced miệng with cửa
# replaced chửi with chửi rủa
# replaced lôi with lôi kéo
# replaced thèm with khao khát
# replaced đầu with đầu tiên
# replaced hạ with chìm
# replaced đi with ngồi bóc lịch
# replaced não with đầu óc
# replaced đầu with thứ một
# replaced nổi with trôi nổi
# replaced mặt with mặt trên cùng
# replaced rảnh with rỗi rãi
# replaced đi with bóc lịch
# replaced đụng with va nhau
# replaced hãm with làm chậm
# replaced đá with sút
# replaced kéo with kéo lê
# replaced kiếm with xoay xở
# replaced móc with moi
# replaced kiểu with lối
# replaced hại with gây hại
# replaced hàng with khuất phục
# replaced thèm with khát khao
# replaced hạ with ngụp
# replaced chửi with chửi rủa
# replaced miệng with cửa
# replaced lôi with kéo vào
# replaced méo with bị trượt phá
# replaced tiếng with ngôn ngữ
# replaced mặt with mặt trên cùng
# replaced đá with đạp
# replaced hãm with làm chậm
# replaced đi with nằm tù
# replaced kiếm with xoay
# replaced tiếng with ngôn ngữ
# replaced thèm with thèm khát
# replaced hàng with chịu thua
# replaced chửi with chửi rủa
# replaced hại with gây hại
# replaced méo with bị trượt phá
# replaced đầu with số một
# replaced đụng with va chạm vào nhau
# replaced lôi with lôi vào
# replaced kiểu with phương kế
# replaced hạ with đắm
# replaced kéo with kéo lê
# replaced rảnh with rỗi
# replaced móc with moi
# replaced miệng with cửa
# replaced não with đầu
# replaced nổi with dập dà dập dềnh
# replaced ngu with vô minh
# replaced ngu with ngu xi
# replaced ngu with tối tăm
# replaced đồ with can lại
# replaced bọn with đám
# replaced vui with hấp dẫn
# replaced già with tuổi già
# replaced vui with hấp dẫn
# replaced mưu with kế
# replaced bọn with đám
# replaced đồ with can
# replaced mưu with mẹo
# replaced bọn with đám
# replaced già with tuổi già
# replaced đồ with can lại
# replaced chắn with chặn
# replaced chết with ngã xuống
# replaced kiếm with xoay xở
# replaced chửi with chửi rủa
# replaced lo with lo liệu
# replaced xong with xong xuôi
# replaced ghét with căm
# replaced thành with bằng
# replaced gửi with kí thác
# replaced xương with khung xương
# replaced tuỷ with tuỷ xương
# replaced tổ with ổ
# replaced chạy with kéo dài
# replaced kiếm with xoay
# replaced chết with tử trận
# replaced thành with là
# replaced xong with chấm dứt
# replaced lo with lo liệu
# replaced kiếm with xoay
# replaced sống with ở tại
# replaced lo with chịu trách nhiệm
# replaced thành with là
# replaced tuỷ with tuỷ xương
# replaced chửi with chửi rủa
# replaced chắn with chặn
# replaced xong with hoàn tất
# replaced gửi with gởi gắm
# replaced học with học bài
# replaced đi with nằm
# replaced đi with ngồi
# replaced ngu with dốt
# replaced ngu with sự tối tăm
# replaced ngu with sự mu muội
# replaced ngu with sự tối tăm
# replaced kiếm with tìm
# replaced bọn with đám
# replaced kiếm with xoay
# replaced bọn with đám
# replaced ngu with sự mu muội
# replaced ngu with tối tăm
# replaced bọn with lũ
# replaced kiếm with tìm
# replaced day with véo yêu
# replaced phai with lan ra
# replaced doi with dải đất
# replaced day with vấu
# replaced phai with loang ra
# replaced day with vấu
# replaced sợ with e sợ
# replaced tinh with tinh xảo
# replaced vương with vương vãi
# replaced hành with hành ta
# replaced hàng with khuất phục
# replaced cỡ with size
# replaced vương with vương vãi
# replaced sợ with e sợ
# replaced hàng with chịu phục
# replaced tinh with tinh xảo
# replaced thụt with lùi
# replaced hành with cây hành
# replaced sợ with lo
# replaced thụt with thụt lùi
# replaced tinh with tinh xảo
# replaced cỡ with size
# replaced vương with không được gom lại
# replaced hành with cây hành ta
# replaced may with khâu
# replaced bố with bốc hơi
# replaced chết with bỏ mạng
# replaced đối with nằm đối diện
# replaced tiêm with tiêm chích
# replaced hành with hành ta
# replaced trốn with tự ý bỏ học
# replaced tắc with làm tắc nghẽn
# replaced mổ with mổ xẻ
# replaced định with vạch
# replaced thằng with gã
# replaced mắn with sai
# replaced phòng with dè chừng
# replaced mắn with sai
# replaced tiêm with tiêm chích
# replaced bố with bốc hơi
# replaced hành with hành ta
# replaced chết with bỏ mạng
# replaced đối with đối diện với
# replaced địt with xì hơi
# replaced may with khâu
# replaced định with vạch
# replaced mổ with mổ xẻ
# replaced thằng with gã
# replaced hành with hành ta
# replaced bố with bốc hơi
# replaced mổ with xẻ
# replaced may with khâu
# replaced bao with quây quanh
# replaced định with định rõ
# replaced trốn with bỏ học
# replaced tiêm with chích
# replaced thằng with gã
# replaced phòng with dè chừng
# replaced mắn with mắn đẻ
# replaced tắc with làm tắc nghẽn
# replaced tu with ở tu viện
# replaced ve with ve áo
# replaced ban with trao
# replaced tu with ở tu viện
# replaced co with thu ngắn
# replaced tu with ở tu viện
# replaced Nguyễn with triều Nguyễn
# replaced ngu with tăm tối
# replaced chửi with chửi rủa
# replaced suy with sút kém
# replaced ngu with sự vô minh
# replaced chủ with người chủ
# replaced thằng with lão
# replaced Nguyễn with nhà Nguyễn
# replaced chửi with chửi rủa
# replaced ỉa with đi ị
# replaced ỉa with đi đại tiện
# replaced ỉa with đại tiện
# replaced dịch with phiên dịch
# replaced trốn with vắng mặt không phép
# replaced sủa with cắn
# replaced trốn with trốn học
# replaced dịch with phiên dịch
# replaced trốn with bỏ việc
# replaced đá with đạp
# replaced xong with kết thúc
# replaced đá with sút
# replaced thi with kiểm tra
# replaced ve with ve áo
# replaced quan with quan lại
# replaced ong with đàn ong
# replaced bo with cho tiền bo
# replaced thi with kiểm tra
# replaced ong with con ong
# replaced quan with quan lại
# replaced bao with quây quanh
# replaced bo with bo cho
# replaced bao with bao quanh
# replaced quan with quan lại
# replaced bo with cho tiền tip
# replaced ve with ve áo
# replaced thi with kiểm tra
# replaced ác with vô nhân tính
# replaced ác with vô nhân tính
# replaced quyền with quyền lực
# replaced nổ with cho nổ tung
# replaced bọn with giới
# replaced bọn with lũ
# replaced chém with cưa
# replaced chém with phạt
# replaced nổ with nổ tung
# replaced đi with nằm
# replaced ngược with ve
# replaced mặt with mặt trên
# replaced mặt with mặt trên cùng
# replaced hiến with hiến dâng
# replaced ngược with trái tay
# replaced hiến with hiến dâng
# replaced mặt with mặt trên
# replaced ngược with ve
# replaced đi with đi tù
# replaced nguy with mối nguy
# replaced xương with khung xương
# replaced gặm with gặm nhấm
# replaced xương with khung xương
# replaced cứt with phân
# replaced đá with đạp
# replaced phó with người thay quyền
# replaced chụp with chụp ảnh
# replaced thành with bằng
# replaced thưởng with ân thưởng
# replaced trần with ở trần
# replaced trao with phong tặng
# replaced đoàn with nhóm nhỏ
# replaced quan with quan lại
# replaced lưu with lưu lại
# replaced ngu with sự ngu xi
# replaced thành with là
# replaced thưởng with khen thưởng
# replaced trần with trần truồng
# replaced lưu with lưu lại
# replaced chụp with chụp ảnh
# replaced đoàn with nhóm
# replaced trao with phong tặng
# replaced chủ with người chủ
# replaced lũ with lũ lụt
# replaced đá with sút
# replaced lũ with lụt lội
# replaced trao with phong
# replaced phó with cấp phó
# replaced quan with quan lại
# replaced chụp with chụp ảnh
# replaced ngu with sự tối tăm
# replaced lưu with vẫn còn
# replaced thưởng with ban thưởng
# replaced trần with khoả thân
# replaced quyền with quyền chi phối
# replaced cướp with cướp của
# replaced bọn with lũ
# replaced quyền with quyền chi phối
# replaced bọn with lũ
# replaced cướp with cướp của cải
# replaced quyền with quyền lực
# replaced bọn with đoàn
# replaced cướp with cướp phá
# replaced dạy with dạy học
# replaced dạy with dạy học
# replaced dạy with dạy học
# replaced cảnh with cảnh quan
# replaced phim with phim điện ảnh
# replaced thằng with lão
# replaced xoá with lau sạch
# replaced luật with bộ luật
# replaced cảnh with cảnh vật
# replaced luật with bộ luật
# replaced thằng with lão
# replaced xoá with tẩy sạch
# replaced phim with phim ảnh
# replaced luật with bộ luật
# replaced phim with phim ảnh
# replaced xoá with xoá đi
# replaced thằng with gã
# replaced cảnh with phong cảnh
# replaced hình with hình thù
# replaced Phan with sông Phan
# replaced hình with hình dạng
# replaced thằng with lão
# replaced hình with hình thù
# replaced Phan with sông Phan
# replaced cướp with cướp phá
# replaced cướp with cướp của cải
# replaced cướp with cướp phá
# replaced cua with thịt cua
# replaced chi with tiêu xài
# replaced day with bấu
# replaced may with khâu
# replaced day with véo
# replaced da with da động vật
# replaced đáp with đáp lại
# replaced lành with lành tính
# replaced hiếp with cưỡng dâm
# replaced lành with vô trùng
# replaced hiếp with cưỡng dâm
# replaced đáp with đáp trả
# replaced lành with vệ sinh
# replaced đáp with đáp trả
# replaced hiếp with hiếp dâm
# replaced đọc with đọc lên
# replaced viết with đánh vần
# replaced bọn with giới
# replaced viết with ghi
# replaced viết with viết theo chính tả
# replaced đọc with đọc lên
# replaced ghét with không thích
# replaced ghét with căm ghét
# replaced ghét with căm ghét
# replaced kiểu with cách thức
# replaced chết with hi sinh
# replaced kiểu with lối
# replaced thằng with lão
# replaced thằng with gã
# replaced thằng with lão
# replaced bó with chữa
# replaced bó with chữa
# replaced bó with bó bột
# replaced đẹp with đẹp đẽ
# replaced hồn with linh hồn
# replaced thần with vị thần
# replaced giáo with giàn giáo
# replaced Đức with Cộng hoà Liên bang Đức
# replaced đường with đường đi
# replaced sẻ with chim sẻ
# replaced chân with phần đế
# replaced tôn with tôn lên
# replaced diệt with hủy diệt
# replaced lạc with đậu phộng
# replaced cứu with cứu nguy
# replaced học with học bài
# replaced hồn with linh hồn
# replaced đẹp with xinh đẹp
# replaced thần with vị thần
# replaced cánh with cánh quạt
# replaced đường with đường chuyển động
# replaced sẻ with chim sẻ
# replaced lạc with đậu phộng
# replaced diệt with trừ tiệt nọc
# replaced chân with phần nền
# replaced giáo with giàn giáo
# replaced Đức with Cộng hoà Liên bang Đức
# replaced cánh with cánh quạt
# replaced hồn with linh hồn
# replaced giáo with giàn giáo
# replaced chân with phần bệ
# replaced lạc with củ lạc
# replaced tôn with tôn lên
# replaced học with học bài
# replaced thần with vị thần
# replaced đẹp with tươi đẹp
# replaced Đức with Deutschland
# replaced cứu with cứu nạn
# replaced diệt with diệt tận gốc
# replaced cam with Citrus sinensis
# replaced giúp with có ích
# replaced giúp with cứu giúp
# replaced gan with gan động vật
# replaced đánh with thổi
# replaced kêu with vang lên
# replaced hồ with hồ cứng
# replaced gan with gan động vật
# replaced kêu with kêu lên
# replaced kêu with vang lên
# replaced chửi with chửi rủa
# replaced đánh with thổi
# replaced phí with hoài
# replaced miễn with tha cho
# replaced giá with phải trả
# replaced phí with lãng phí
# replaced giá with phải trả
# replaced đi with bóc lịch
# replaced miễn with miễn trừ
# replaced phí with hoài
# replaced Tiền with sông Tiền
# replaced Nguyễn with nhà Nguyễn
# replaced Nguyễn with nhà Nguyễn
# replaced Nguyễn with triều Nguyễn
# replaced đi with dựa cột
# replaced địt with trung tiện
# replaced bọn with đoàn
# replaced đòi with đưa ra
# replaced bọn with đám
# replaced thử with kiểm tra
# replaced đòi with yêu cầu
# replaced mẹ with sinh vật mẹ
# replaced thành with bằng
# replaced thử with kiểm tra
# replaced phố with khu cao tầng
# replaced địt with đánh địt
# replaced cướp with cướp của cải
# replaced phát with phân phát
# replaced kéo with kéo lê
# replaced ngu with tối
# replaced não with đầu
# replaced cướp with cướp của
# replaced kéo with kéo lê
# replaced ngu with dốt
# replaced phát with cấp phát
# replaced não with đầu óc
# replaced cướp with cướp của
# replaced kéo with kéo lê
# replaced ngu with tăm tối
# replaced não with đầu
# replaced phát with phân phát
# replaced trâu with trâu sông
# replaced trâu with trâu nước
# replaced trâu with trâu nước
# replaced viết with viết theo chính tả
# replaced chờ with chờ đợi
# replaced viết with chép
# replaced chờ with chờ đợi
# replaced chửi with chửi rủa
# replaced viết with đánh vần
# replaced thầy with giáo viên
# replaced thầy with người thầy
# replaced thầy with thầy giáo
# replaced não with đầu óc
# replaced não with đầu
# replaced não with óc
# replaced cai with cai rượu
# replaced me with cây me
# replaced me with cây me
# replaced ban with ban phát
# replaced lai with cho lai giống
# replaced me with cây me
# replaced thức with không ngủ
# replaced may with khâu
# replaced đè with việc nén
# replaced chết with tử trận
# replaced sót with bỏ quên
# replaced chiều with nuông
# replaced chiều with chiều chuộng
# replaced đè with nén
# replaced sông with dòng sông
# replaced thức with tỉnh
# replaced mắn with sai quả
# replaced may with khâu
# replaced mắn with sai
# replaced thức with tỉnh
# replaced phân with chia tách
# replaced chết with bỏ mạng
# replaced đè with việc đè
# replaced may with khâu
# replaced mặt with mặt trên
# replaced sợ with lo ngại
# replaced sợ with lo ngại
# replaced mặt with mặt trên cùng
# replaced sợ with lo
# replaced mặt with mặt trên
# replaced thầy with người thầy
# replaced thầy with thầy giáo
# replaced thầy with giáo viên
# replaced hàng with quy hàng
# replaced đi with bóc lịch
# replaced chiến with đóng giữ
# replaced quân with quân bài
# replaced yên with để yên
# replaced tâm with trung điểm
# replaced hàng with quy hàng
# replaced lính with quân lính
# replaced đội with đội mũ nón
# replaced quân with quân bài
# replaced yên with để yên
# replaced tâm with trung điểm
# replaced lính with quân lính
# replaced đội with mang nón
# replaced yên with để yên
# replaced chiến with chiếm đóng
# replaced sinh with sinh ở
# replaced quân with quân bài
# replaced truyền with lây
# replaced biến with thay đổi
# replaced thành with là
# replaced lạc with đậu phụng
# replaced biến with thay đổi
# replaced lạc with củ lạc
# replaced tuyên with tuyên án
# replaced truyền with lây
# replaced tuyên with tuyên án
# replaced biến with thay đổi
# replaced đánh with làm cho kêu
# replaced truyền with lây
# replaced me with cây me
# replaced no with trạng thái no nê
# replaced no with trạng thái no nê
# replaced thằng with gã
# replaced tập with luyện tập
# replaced tập with luyện tập
# replaced thằng with gã
# replaced tập with rèn luyện
# replaced mai with cái mai
# replaced vang with lan truyền
# replaced ham with ham mê
# replaced me with cây me
# replaced tiên with thần tiên
# replaced đu with xà treo;
# replaced bi with bi thuốc
# replaced ham with ham mê
# replaced vang with lan toả
# replaced đu with đu nhào nhộn
# replaced no with trạng thái no nê
# replaced đu with xà treo;
# replaced vang with lan
# replaced me with cây me
# replaced ham with ham mê
# replaced tham with dã tâm
# replaced đích with vạch đích
# replaced đích with vạch đích
# replaced đích with vạch đích đường đua ngựa
# replaced tiên with thần tiên
# replaced lũ with lụt lội
# replaced quan with quan lại
# replaced Trần with triều đại Trần
# replaced tù with ngục
# replaced tội with sai lầm
# replaced Nga with chế độ Nga hoàng
# replaced tù with trại giam
# replaced tội with sai lầm
# replaced Nga with Đế quốc Nga
# replaced bắt with bắt phải chịu đựng
# replaced Trần with triều nhà Trần
# replaced phát with cấp
# replaced chỗ with chỗ trống
# replaced chết with tử mạng
# replaced điện with đánh dây thép
# replaced chết with thiệt mạng
# replaced kế with thủ đoạn
# replaced điện with đánh dây thép
# replaced lộ with phơi bày
# replaced tỉnh with tỉnh lại
# replaced kế with âm mưu
# replaced chết with tử trận
# replaced phát with phân phát
# replaced thằng with lão
# replaced ngu with sự ngu xi
# replaced hợp with hợp nhau
# replaced trường with trường lực
# replaced teo with bớt đi
# replaced mẹ with sinh vật mẹ
# replaced hợp with hợp nhau
# replaced teo with vợi đi
# replaced ví with bóp tiền
# replaced ngu with tối tăm
# replaced mẹ with sinh vật mẹ
# replaced chửi with chửi rủa
# replaced teo with hao bớt
# replaced ngu with sự ngu muội
# replaced hợp with hợp nhau
# replaced phóng with chiếu
# replaced phóng with chiếu
# replaced phóng with chiếu
# replaced mẹ with sinh vật mẹ
# replaced hát with ca
# replaced mẹ with sinh vật mẹ
# replaced hát with ca
# replaced mẹ with sinh vật mẹ
# replaced hát with xướng ca
# replaced cai with cai nghiện
# replaced cai with cai rượu
# replaced cai with cai nghiện
# replaced khóc with khóc lóc
# replaced cộng with gộp
# replaced cười with mỉm cười
# replaced giả with giả tạo
# replaced lừa with lừa đảo
# replaced cười with mỉm cười
# replaced khóc with khóc lóc
# replaced cộng with cộng gộp
# replaced khóc with khóc lóc
# replaced cộng with lấy tổng
# replaced giả with giả tạo
# replaced cười with mỉm cười
# replaced phân with chia tách
# replaced não with đầu
# replaced bò with bò trườn
# replaced gái with bớp
# replaced phân with phân chia
# replaced chửi with chửi rủa
# replaced não with óc
# replaced bò with trườn
# replaced gái with gái điếm
# replaced não with đầu óc
# replaced phân with phân chia
# replaced chửi with chửi rủa
# replaced chắn with chặn
# replaced Man with đảo Man
# replaced Man with đảo Man
# replaced chắn with ngăn
# replaced Man with đảo Man
# replaced chắn with chặn
# replaced giàu with giàu có
# replaced giàu with phong phú
# replaced giàu with giàu có
# replaced lợi with có lợi
# replaced nạn with tai biến
# replaced xe with phương tiện vận chuyển
# replaced xoá with xoá tan đi
# replaced lưu with lưu lại
# replaced xe with phương tiện vận chuyển
# replaced lợi with có lợi
# replaced xoá with xoá bỏ
# replaced lưu with lưu lại
# replaced quyền with quyền thống trị
# replaced xoá with xoá tan đi
# replaced nạn with tai ương
# replaced xe with phương tiện vận chuyển
# replaced lưu with vẫn còn
# replaced quyền with quyền lực
# replaced dao with gươm
# replaced quan with quan lại
# replaced day with bấu
# replaced quan with quan lại
# replaced quan with quan lại
# replaced coi with trông
# replaced gọi with chào gọi
# replaced sản with khoa phụ sản
# replaced gọi with chào
# replaced đu with xà treo;
# replaced lũ with lụt lội
# replaced chửi with chửi rủa
# replaced no with trạng thái no nê
# replaced nghi with ngờ vực
# replaced lai with lai giống
# replaced nghi with nghi hoặc
# replaced lai with cho lai giống
# replaced xong with kết thúc
# replaced no with trạng thái no nê
# replaced xong with chấm dứt
# replaced lai with lai giống
# replaced quan with quan lại
# replaced xây with làm
# replaced thằng with gã
# replaced lôi with kéo
# replaced lạc with củ lạc
# replaced vãi with để đổ
# replaced cười with mỉm cười
# replaced coi with trông thi
# replaced thằng with lão
# replaced đồ with can
# replaced khí with chất khí
# replaced ngô with hạt ngô
# replaced quan with quan lại
# replaced đá with sút
# replaced tượng with con tượng
# replaced phấn with phấn trắng
# replaced xây with làm
# replaced phấn with phấn viết bảng
# replaced vãi with làm rơi
# replaced lùng with sục
# replaced đá with sút
# replaced thằng with gã
# replaced quan with quan lại
# replaced đồ with can
# replaced mặt with mặt trên
# replaced nội with nội bộ
# replaced chửi with chửi rủa
# replaced chủ with chủ lao động
# replaced đứng with đứng trên
# replaced chủ with chủ lao động
# replaced mặt with mặt trên cùng
# replaced phạt with bắt phạt ai
# replaced mặt with mặt trên
# replaced phạt with phạt vạ ai
# replaced đứng with bám sát
# replaced giả with không tự nhiên
# replaced nhiễm with bám lấy
# replaced giấu with che đậy
# replaced Trung with sông Trung
# replaced giấu with che giấu
# replaced Trung with sông Trung
# replaced nhiễm with đeo bám
# replaced nhiễm with bám lấy
# replaced Trung with sông Trung
# replaced chuyên with chuyên biệt
# replaced rách with thủng
# replaced rách with thủng
# replaced rách with thủng
# replaced giúp with cứu viện
# replaced chữa with chữa trị
# replaced thịt with cùi
# replaced xấu with tội lỗi
# replaced kích with cái kích
# replaced chạy with kéo dài
# replaced chạy with trải dài
# replaced thịt with cùi
# replaced kích with cái kích
# replaced chữa with trị bệnh
# replaced xấu with đen tối
# replaced giúp with giúp ích
# replaced chữa with chữa trị
# replaced kích with cái kích
# replaced chạy with kéo dài
# replaced xấu with độc địa
# replaced giúp with giúp đỡ
# replaced thịt with cùi
# replaced hại with làm hại
# replaced ngu with sự ngu xi
# replaced hại with làm hại
# replaced thương with đồng cảm
# replaced thương with trắc ẩn
# replaced hại with làm hại
# replaced tí with một chút
# replaced trung with giống trung
# replaced tí with một tẹo
# replaced quan with quan lại
# replaced ác with độc ác
# replaced cộng with gộp
# replaced ôn with ôn tập
# replaced ôn with luyện
# replaced ác with vô nhân tính
# replaced bọn with lũ
# replaced cá with cá cược
# replaced ôn with tập luyện
# replaced cộng with cộng gộp
# replaced quan with quan lại
# replaced sản with khoa sản
# replaced kêu with kêu lên
# replaced dạy with dạy học
# replaced dạy with dạy học
# replaced khoang with ổ
# replaced khoang with hố
# replaced khoác with trùm lên
# replaced ca with ca làm việc
# replaced ca with phiên
# replaced ca with phiên làm việc
# replaced rảnh with rỗi
# replaced rảnh with rảnh rỗi
# replaced nội with nội bộ
# replaced mẹ with sinh vật mẹ
# replaced chết with hi sinh
# replaced mẹ with sinh vật mẹ
# replaced lũ with lụt
# replaced tích with cóp nhặt
# replaced thành with là
# replaced cu with chim cu
# replaced thầy with người thầy
# replaced cu with chim cu
# replaced quần with quần dài
# replaced đầu with số một
# replaced đầu with nhất
# replaced vãi with làm rơi
# replaced gáy with ót
# replaced mẹ with sinh vật mẹ
# replaced mẹ with sinh vật mẹ
# replaced vãi with để đổ ra
# replaced địt with trung tiện
# replaced địt with đánh rắm
# replaced vãi with làm rơi
# replaced gáy with ót
# replaced đi with ngồi
# replaced giải with tìm
# replaced gái with ca ve
# replaced thành with là
# replaced đàn with tốp
# replaced giải with tìm mật mã
# replaced gái with đĩ
# replaced vay with vay mượn
# replaced đi with ngồi bóc lịch
# replaced mặt with mặt trên
# replaced khắc with điền
# replaced búa with cái búa
# replaced kiến with con kiến
# replaced sống with cư trú
# replaced chí with điểm chí
# replaced phúc with phúc tổ
# replaced gương with cái gương
# replaced tức with bực tức
# replaced quang with quang quẻ
# replaced hô with hô đi hô lại
# replaced thoại with mẩu đối thoại
# replaced quang with quang quẻ
# replaced xử with phân xử
# replaced kiến with con kiến
# replaced phúc with phúc đức
# replaced búa with cái búa
# replaced đảng with đảng phái
# replaced hữu with lề phải
# replaced liềm with hái
# replaced gương with cái gương
# replaced lộ with phơi bày
# replaced chí with điểm chí
# replaced búa with cái búa
# replaced hữu with lề phải
# replaced tức with tức bực
# replaced phúc with phúc tổ
# replaced gương with cái gương
# replaced khắc with điền chữ
# replaced quang with quang đãng
# replaced đảng with đảng phái
# replaced kiến with con kiến
# replaced sống with định cư
# replaced vay with vay mượn
# replaced oi with oi bức
# replaced vay with vay mượn
# replaced thằng with gã
# replaced thằng with gã
# replaced thằng with gã
# replaced lượt with hiệp
# replaced giao with cắt cử
# replaced xong with xong xuôi
# replaced xếp with phân loại
# replaced liếm with liếm láp
# replaced mút with bú
# replaced tình with tình cảm
# replaced hàng with khuất phục
# replaced bắn with bắn hạ
# replaced mút with bú
# replaced giao with uỷ thác
# replaced bắt with bắt phải chịu đựng
# replaced liếm with liếm láp
# replaced tình with xúc cảm
# replaced lượt with hiệp
# replaced mẹ with sinh vật mẹ
# replaced bắn with bắn hạ
# replaced chờ with đợi
# replaced chờ with đợi
# replaced xếp with phân loại
# replaced mút with bú
# replaced liếm with liếm láp
# replaced mẹ with sinh vật mẹ
# replaced lượt with hiệp
# replaced hàng with chịu phục
# replaced bắn with bắn hạ
# replaced tinh with tinh xảo
# replaced đi with đi tù
# replaced đi with ngồi tù
# replaced đi with dựa cột
# replaced máu with huyết
# replaced cầm with nắm
# replaced cu with chim cu cu
# replaced đạo with ăn cắp ý tưởng
# replaced phạm with xâm phạm
# replaced chất with chất đầy
# replaced tài with điệu nghệ
# replaced quyền with quyền thế
# replaced độc with độc hại
# replaced quyết with quyết tâm
# replaced phạm with vi phạm
# replaced cầm with nắm
# replaced đạo with ăn cắp ý
# replaced hút with hấp thụ
# replaced chất with đổ đầy
# replaced máu with huyết
# replaced tài with điêu luyện
# replaced độc with không lành
# replaced đạo with trộm ý tưởng
# replaced chất with đổ đầy
# replaced phạm with vi phạm
# replaced cầm with nắm
# replaced cu with cu cu
# replaced máu with huyết
# replaced gốc with gộc cây
# replaced cộng with gộp
# replaced trơ with chai lì
# replaced sản with khoa phụ sản
# replaced trơ with mặt dày
# replaced sản with khoa phụ sản
# replaced bò with bò trườn
# replaced bò with trườn
# replaced bò with trườn
# replaced no with trạng thái no nê
# replaced no with trạng thái no nê
# replaced no with trạng thái no nê
# replaced ngu with sự ngu muội
# replaced ngu with sự tăm tối
# replaced ngu with sự mu muội
# replaced xấu with độc địa
# replaced nhập with sáp nhập
# replaced thành with bằng
# replaced mặt with mặt trên
# replaced nhập with gộp lại
# replaced mặt with mặt trên cùng
# replaced xấu with độc địa
# replaced thành with bằng
# replaced mặt with mặt trên cùng
# replaced xấu with đen tối
# replaced thành with là
# replaced nhập with gộp lại
# replaced đu with xà treo;
# replaced may with khâu
# replaced đu with đu nhào nhộn
# replaced cộng with gộp
# replaced xua with xua tan
# replaced thịt with cùi
# replaced sát with xay
# replaced trung with giống trung
# replaced da with da động vật
# replaced bọn with đám
# replaced nhét with ních
# replaced trung with giống trung
# replaced quân with quân bài
# replaced nhét with nhồi nhét
# replaced nhồi with nhồi vào
# replaced xua with xua tan
# replaced quân with quân bài
# replaced chiến with chiếm đoạt
# replaced đầu with số một
# replaced đi with dựa cột
# replaced giáo with giàn giáo
# replaced đầu with nhất
# replaced khám with xét
# replaced giáo with giàn giáo
# replaced đầu with đầu tiên
# replaced khám with xem xét
# replaced giáo with giàn giáo
# replaced nữ with thuộc phụ nữ
# replaced nữ with thuộc về phụ nữ
# replaced trai with thịt trai
# replaced mẹ with sinh vật mẹ
# replaced sếp with ông chủ
# replaced mẹ with sinh vật mẹ
# replaced tham with hoài bão
# replaced tham with dã tâm
# replaced tham with tham lam
# replaced đạo with trộm ý tưởng
# replaced đạo with ăn cắp
# replaced đạo with ăn cắp ý tưởng
# replaced Lào with đất nước Triệu Voi
# replaced Lào with Vạn Tượng
# replaced Lào with Vạn Tượng
# replaced bọn with đoàn
# replaced thú with động vật có vú
# replaced thú with động vật có vú
# replaced chửi with chửi rủa
# replaced chửi with chửi rủa
# replaced vui with thích thú
# replaced giỏi with tài năng
# replaced bốc with phun
# replaced bốc with phun khói
# replaced giỏi with tài năng
# replaced giỏi with tài năng
# replaced bốc with toả
# replaced bò with bò trườn
# replaced bò with bò trườn
# replaced bò with trườn
# replaced đàn with tốp
# replaced đàn with bầy
# replaced đàn with bầy
# replaced đạo with ăn cắp ý
# replaced đa with nhiều
# replaced kết with xe
# replaced sống with định cư
# replaced bọn with đám
# replaced tình with xúc cảm
# replaced đạo with ăn cắp
# replaced sống with ngụ
# replaced tình with xúc cảm
# replaced đa with nhiều
# replaced kết with xoắn
# replaced bọn with giới
# replaced kết with xe
# replaced sống with định cư
# replaced đạo with trộm ý tưởng
# replaced đa with nhiều
# replaced bọn with đám
# replaced tình with xúc cảm
# replaced gọi with chào gọi
# replaced điện with đánh dây thép
# replaced quan with quan lại
# replaced nội with nội bộ
# replaced điện with đánh dây thép
# replaced nội with nội bộ
# replaced chửi with chửi rủa
# replaced quan with quan lại
# replaced gọi with chào gọi
# replaced quan with quan lại
# replaced chửi with chửi rủa
# replaced nội with nội bộ
# replaced ghen with ghen tuông
# replaced sủa with cắn
# replaced ngu with tối
# replaced giàu with giàu có
# replaced ngu with tăm tối
# replaced kia with bên kia
# replaced kia with còn lại
# replaced giàu with giàu có
# replaced ghen with ghen tuông
# replaced hồng with Diospyros kaki
# replaced tẩy with tẩy trắng
# replaced gian with quầy hàng
# replaced gian with quầy
# replaced tẩy with làm trắng
# replaced hồng with Diospyros kaki
# replaced công with công cơ học
# replaced phụ with phụ vào
# replaced hồng with Diospyros kaki
# replaced đóng with kết thúc
# replaced nổi with rập rình
# replaced nổi with dập dềnh
# ...
# replaced xanh with xanh lam
# replaced xanh with trở thành xanh lam
# replaced mặt with mặt trên
# replaced động with hanh lớn
# replaced đuổi with trừ
# replaced củ with thân củ
# replaced định with vạch
# replaced động with hanh lớn
# replaced củ with thân củ
# replaced định with nhìn ra
# replaced đuổi with loại bỏ
# replaced định with vạch ra
# replaced củ with thân củ
# replaced đuổi with loại bỏ
# replaced động with hanh lớn
# replaced khung with cốt
# replaced thang with cái thang
# replaced thang with bậc
# replaced đạo with ăn cắp ý
# replaced quy with bắt phải chịu
# replaced quy with đánh (thuế)
# replaced thai with phôi thai
# replaced đâm with chọc
# replaced chôn with mai táng
# replaced chết with ngã xuống
# replaced hồn with linh hồn
# replaced roi with cái roi
# replaced mặt with mặt trên
# replaced sống with ở
# replaced phách with thanh gõ phách
# replaced mặt with mặt trên cùng
# replaced thai with phôi thai
# replaced sống with ngụ
# replaced sắt with Fe
# replaced hồn with linh hồn
# replaced chôn with mai táng
# replaced tán with tìm hiểu
# replaced đào with bới
# replaced tán with theo đuổi
# replaced đâm with đâm xuống
# replaced buồn with buồn bã
# replaced roi with cái roi
# replaced phách with thanh gõ phách
# replaced đầu with một
# replaced thai with bào thai
# replaced tức with bực tức
# replaced tức with bực tức
# replaced tức with tức bực
# replaced mặt with mặt trên cùng
# replaced chết with thiệt mạng
# replaced mặt with mặt trên
# replaced chết with bỏ mạng
# replaced mặt with mặt trên
# replaced chết with thiệt mạng
# replaced lờ with phớt đi
# replaced lờ with bơ
# replaced lờ with bơ
# replaced coi with trông thi
# replaced may with khâu
# replaced day with bấu
# replaced may with khâu
# replaced bát with chén
# replaced day with bấu
# replaced song with khung song
# replaced coi with trông
# replaced yên with để yên
# replaced day with vấu
# replaced day with véo yêu
# replaced day with day day
# replaced nhảy with khiêu vũ
# replaced địch with đối địch
# replaced kiểu with phương kế
# replaced cướp with cướp bóc
# replaced thằng with lão
# replaced chống with phản đối
# replaced tức with tức bực
# replaced đứng with theo như
# replaced quen with quen thói
# replaced cướp with cướp bóc
# replaced thằng with gã
# replaced kiểu with phương kế
# replaced chống with phản đối
# replaced địch with thù địch
# replaced tức with tức bực
# replaced coi with coi thi
# replaced quen with quen thói
# replaced nhảy with khiêu vũ
# replaced tức with tức bực
# replaced địch with đối địch
# replaced cướp with cướp phá
# replaced kiểu with lối
# replaced nhảy with khiêu vũ
# replaced coi with trông
# replaced đứng with đứng trên
# replaced quen with thói quen
# replaced thằng with gã
# replaced mua with đút lót
# replaced ảo with không thực
# replaced bắt with bắt phải chịu
# replaced phá with chống cự lại
# replaced hoa with cây lấy hoa
# replaced hưởng with hưởng thụ
# replaced Trần with triều Trần
# replaced chửi with chửi rủa
# replaced thức with không ngủ
# replaced dao with gươm
# replaced sống with cư trú
# replaced đập with co bóp
# replaced chi with chi tiền
# replaced hàng with đầu hàng
# replaced giá with trị giá
# replaced ảnh with bức hình
# replaced lôi with lôi kéo
# replaced mua with đút lót
# replaced thức with tỉnh
# replaced hưởng with hưởng thụ
# replaced lôi with kéo
# replaced sống with ở tại
# replaced bắt with bắt phải chịu
# replaced dao with kiếm
# replaced hoa with cây cho hoa
# replaced ảnh with bức ảnh
# replaced ảo with không thực
# replaced chửi with chửi rủa
# replaced phá with chống cự lại
# replaced hàng with chịu phục
# replaced đập with co bóp
# replaced chi with tiêu xài
# replaced Trần with triều Trần
# replaced giá with trị giá
# replaced ảo with hư ảo
# replaced chửi with chửi rủa
# replaced hưởng with hưởng thụ
# replaced giá with trị giá
# replaced ảnh with tấm hình
# replaced chi with tiêu
# replaced phá with chống cự
# replaced thức with không ngủ
# replaced sống with ở tại
# replaced lôi with kéo
# replaced mua with mua chuộc
# replaced hoa with cây hoa
# replaced Trần with triều Trần
# replaced đập with co bóp
# replaced dao with gươm
# replaced bắt with bắt phải chịu đựng
# replaced hàng with khuất phục
# replaced kết with bện
# replaced phát with cấp phát
# replaced bọn with lũ
# replaced trốn with tự ý bỏ việc
# replaced phát with phân phát
# replaced trốn with bỏ việc
# replaced kết with xoắn
# replaced bọn with giới
# replaced phát with cấp phát
# replaced cuồng with chứng cuồng
# replaced kết with bện
# replaced trốn with tự ý bỏ học
# replaced diện with chưng diện
# replaced vàng with màu vàng
# replaced Tiền with sông Tiền
# replaced Mĩ with U.S.
# replaced trộm with ăn trộm bẻ khoá
# replaced Mĩ with U.S.
# replaced Tiền with sông Tiền
# replaced trộm with lấy trộm
# replaced diện with chưng diện
# replaced vàng with trở nên vàng
# replaced diện with chưng diện
# replaced vàng with trở nên vàng
# replaced Tiền with Tiền Giang
# replaced Mĩ with nước Mĩ
# replaced trộm with ăn trộm ban đêm
# replaced trai with thịt trai
# replaced trai with thịt trai
# replaced trai with thịt trai
# replaced trần with khoả thân
# replaced cá with cược
# replaced già with tuổi già
# replaced đẹp with xinh đẹp
# replaced chửi with chửi rủa
# replaced đầu with số 1
# replaced đi with ngồi bóc lịch
# replaced chấm with tạo chấm
# replaced đá with đạp
# replaced chửi with chửi rủa
# replaced đẹp with xinh
# replaced đá with đạp
# replaced dạy with dạy học
# replaced già with năm tháng cuối đời
# replaced đi with bóc lịch
# replaced chấm with tạo chấm
# replaced cá with cược
# replaced đoàn with nhóm nhỏ
# replaced chửi with chửi rủa
# replaced đoàn with đoàn nhỏ
# replaced già with tuổi già
# replaced đá with đạp
# replaced chấm with tạo chấm
# replaced trần with khoả thân
# replaced đi with dựa cột
# replaced cá with cá cược
# replaced đẹp with đẹp đẽ
# replaced cai with cai nghiện
# replaced cai with cai nghiện
# replaced cai with cai nghiện
# replaced thằng with gã
# replaced trông with trông giống với
# replaced thằng with lão
# replaced ngu with vô minh
# replaced thằng with lão
# replaced sói with chó sói
# replaced tù with nhà tù
# replaced lộ with lộ ra
# replaced rối with con rối
# replaced cầm with nắm
# replaced tội with lỗi
# replaced tội with lỗi
# replaced tù with tù đày
# replaced lộ with phát lộ
# replaced tiết with thải
# replaced rối with con rối
# replaced tội with sai lầm
# replaced tiết with thải
# replaced tù with ngục
# replaced rối with bù nhìn
# replaced cầm with nắm
# replaced bao with bao quanh
# replaced đi with dựa cột
# replaced bao with quây quanh
# replaced đi with bóc lịch
# replaced bao with bao quanh
# replaced đi with dựa cột
# replaced thằng with gã
# replaced thằng with lão
# replaced thằng with gã
# replaced gào with gào lên
# replaced thét with hét
# replaced thét with hét
# replaced lũ with lụt
# replaced sủa with cắn
# replaced đi with nằm
# replaced định with xác định rõ
# replaced sủa with cắn
# replaced đi with ngồi tù
# replaced định with xác định
# replaced lợn with thịt lợn
# replaced biển with đại dương
# replaced định with vạch ra
# replaced sủa with cắn
# replaced lợn with thịt heo
# replaced đạo with ăn cắp ý
# replaced bọn with đám
# replaced tế with tế lễ
# replaced vãi with để đổ
# replaced đường with đường đi
# replaced tế with hiến tế
# replaced đạo with ăn cắp ý tưởng
# replaced vãi with đánh đổ
# replaced đạo with ăn cắp
# replaced bọn with lũ
# replaced thực with thật
# replaced tế with tế thần
# replaced tham with dã tâm
# replaced độc with hại
# replaced chắn with ngăn
# replaced quan with quan lại
# replaced yêu with thương
# replaced phong with bổ nhậm chỉ định
# replaced dạo with bắt đầu
# replaced chết with thiệt mạng
# replaced vàng with màu vàng
# replaced thời with lúc
# replaced niên with năm
# replaced chết with hi sinh
# replaced tiết with bài tiết
# replaced đeo with cõng
# replaced đảng with phái
# replaced nghèo with nghèo đói
# replaced chặt with chặt bằng rìu
# replaced dạo with dạo đầu
# replaced ngu with sự vô minh
# replaced niên with năm
# replaced yêu with thương
# replaced vàng with trở nên vàng
# replaced phong with bổ nhiệm
# replaced tham with dã tâm
# replaced chết with ngã xuống
# replaced chặt with đẽo bằng rìu
# replaced đeo with cõng
# replaced đảng with đảng phái
# replaced vàng with trở nên vàng
# replaced thời with thời kỳ
# replaced tường with bức tường
# replaced quan with quan lại
# replaced niên with năm
# replaced xui with xúi giục
# replaced xui with giục giã
# replaced xui with hối thúc
# replaced bẩn with vấy bẩn
# replaced may with khâu
# replaced may with khâu
# replaced bẩn with vấy bẩn
# replaced bẩn with vấy bẩn
# replaced may with khâu
# replaced xuất with xuất ra
# replaced phố with khu phố
# replaced nhiễm with bám lấy
# replaced đẹp with đẹp tươi
# replaced ô with ngăn
# replaced đẹp with đẹp tươi
# replaced thành with bằng
# replaced phố with khu cao tầng
# replaced ô with ngăn
# replaced mù with mù mắt
# replaced nhiễm with đeo bám
# replaced thành with bằng
# replaced ô with ngăn
# replaced đẹp with tươi đẹp
# replaced phố with khu cao tầng
# replaced Best with C._H._Best
# replaced Best with C._H._Best
# replaced Best with C._H._Best
# replaced nết with tâm
# replaced xấu with độc địa
# replaced xấu with độc địa
# replaced nết with tâm hồn
# replaced nết with tâm hồn
# replaced xấu with tội lỗi
# replaced khắc with đánh dấu
# replaced khắc with viết chữ
# replaced khắc with viết chữ
# replaced mẹ with sinh vật mẹ
# replaced sướng with sự vui sướng
# replaced sướng with sự sung sướng
# replaced vả with cây vả
# replaced quan with quan lại
# replaced ngu with ngu xi
# replaced mặt with mặt trên cùng
# replaced bố with bốc hơi
# replaced mẹ with sinh vật mẹ
# replaced khôn with thạo đời
# replaced mặt with mặt trên
# replaced mẹ with sinh vật mẹ
# replaced bố with bốc hơi
# replaced ngu with vô minh
# replaced khôn with thạo đời
# replaced vả with cây vả
# replaced hồ with hồ cứng
# replaced hồ with hồ cứng
# replaced bố with bốc hơi
# replaced mẹ with sinh vật mẹ
# replaced ngu with ngu xi
# replaced vả with cây vả
# replaced khôn with thạo đời
# replaced mặt with mặt trên cùng
# replaced não with óc
# replaced não with đầu
# replaced não with óc
# replaced roi with cái roi
# replaced chửi with chửi rủa
# replaced cá with đánh cuộc
# replaced roi with cái roi
# replaced chửi with chửi rủa
# replaced cai with cai nghiện
# replaced nam with S
# replaced cá with đánh cược
# replaced tượng with quân tượng
# replaced khối with hình khối
# replaced khối with hình khối
# replaced khối with hình khối
# replaced học with học bài
# replaced học with học bài
# replaced học with học bài
# replaced mặc with phó mặc
# replaced mặc with để mặc
# replaced kiểu with phương pháp
# replaced công with công cơ học
# replaced công with công cơ học
# replaced bới with tìm
# replaced nghèo with cảnh nghèo
# replaced nghèo with nghèo nàn
# replaced nghèo with nghèo khổ
# replaced sửa with trang bị lại
# replaced sửa with chỉnh sửa
# replaced sửa with tu chỉnh
# replaced công with công cơ học
# replaced bê with thịt bê
# replaced vuốt with vuốt ve
# replaced bê with thịt bê
# replaced hàng with quy phục
# replaced vuốt with xoa xoa
# replaced hàng with chịu phục
# replaced công with công cơ học
# replaced máu with tiết
# replaced lan with loang
# replaced đi with bóc lịch
# replaced thành with là
# replaced lây with lan
# replaced ổ with ổ bệnh
# replaced đi with bóc lịch
# replaced thành with là
# replaced đóng with kết thúc
# replaced lây with lan
# replaced mẹ with sinh vật mẹ
# replaced bao with bao quanh
# replaced đóng with kết thúc
# replaced đi with ngồi bóc lịch
# replaced thành with là
# replaced mẹ with sinh vật mẹ
# replaced tiếng with ngôn ngữ
# replaced dạo with dạo đầu
# replaced hàn with hàn lại
# replaced diện with chưng diện
# replaced lí with dặm Trung Quốc
# replaced sống with trú ngụ
# replaced sống with ở tại
# replaced dạo with bắt đầu
# replaced tiếng with ngôn ngữ
# replaced diện with chưng diện
# replaced hàn with hàn lại
# replaced lí with dặm Trung Quốc
# replaced lí with dặm Trung Quốc
# replaced tiếng with ngôn ngữ
# replaced dạo with mở đầu
# replaced sống with cư trú
# replaced diện with chưng diện
# replaced hàn with hàn lại
# replaced lợi with có lợi
# replaced lợi with có lợi
# replaced lợi with có lợi
# replaced tuyên with tuyên cáo có tội
# replaced tuyên with phán quyết
# replaced tuyên with tuyên cáo có tội
# replaced quen with thói quen
# replaced quen with thói quen
# replaced quen with thói quen
# replaced viết with viết chính tả
# replaced bố with bốc hơi
# replaced bố with bốc hơi
# replaced hoa with cây lấy hoa
# replaced hoa with cây cho hoa
# replaced hoa with cây lấy hoa
# replaced ngăn with giữ
# replaced thánh with vị thánh
# replaced chặn with ngừa
# replaced báo with thông báo
# replaced xong with xong xuôi
# replaced chờ with đợi
# replaced bao with quây quanh
# replaced xong with hoàn tất
# replaced báo with báo cho biết
# replaced thánh with thánh nhân
# replaced ngăn with giữ
# replaced chờ with đợi chờ
# replaced chờ with chờ đợi
# replaced chặn with ngăn ngừa
# replaced ngăn with giữ
# replaced bao with quây quanh
# replaced thánh with thánh nhân
# replaced xong with hoàn tất
# replaced hoang with bị bỏ rơi
# replaced hoang with không ai nhìn nhận
# replaced hoang with bỏ hoang
# replaced ngu with sự tối tăm
# replaced bang with tiểu bang
# replaced bang with tiểu bang
# replaced thằng with gã
# replaced xe with phương tiện vận chuyển
# replaced dạy with dạy học
# replaced vặt with bứt
# replaced chủ with người chủ
# replaced quan with quan lại
# replaced soát with kiểm lại
# replaced chủ with người chủ
# replaced vặt with hái
# replaced soát with thẩm tra
# replaced quan with quan lại
# replaced chủ with chủ lao động
# replaced vặt with hái
# replaced soát with xác minh
# replaced quan with quan lại
# replaced lợi with có lợi
# replaced vớ with rớ
# replaced vớ with rớ
# replaced lợi with có lợi
# replaced lợi with có lợi
# replaced vớ with nhặt được
# replaced thằng with lão
# replaced bom with quả bom
# replaced bom with quả bom
# replaced sản with phụ sản
# replaced cộng with cộng gộp
# replaced thay with thay chỗ
# replaced loài with thành viên
# replaced đổi with hoán đổi
# replaced sản with sản khoa
# replaced kiến with con kiến
# replaced kiến with con kiến
# replaced kiến with con kiến
# replaced đá with sút
# replaced thầy with người thầy
# replaced đá with sút
# replaced tham with tham vọng
# replaced miếng with mồm
# replaced kiểu with phương kế
# replaced bắt with bắt phải chịu
# replaced tham with hoài bão
# replaced kiểu with cách
# replaced kiểu with cách
# replaced miếng with mồm
# replaced tham with tham lam
# replaced nho with cây nho
# replaced bi with bi thuốc
# replaced khung with cốt
# replaced bi with bi thuốc
# replaced khung with xương
# replaced bi with bi thuốc
# list index out of range
# ['"@Dad ‘S - ""Mỹ ác hơn tàu chứ bạn ơi""']
# list index out of range
# ['Tàu ác hơn Mỹ trăm lần chứ bạn ơi']
# replaced Trung with sông Trung
# replaced phủ with bao xung quanh
# replaced mộng with ảo mộng
# replaced gian with gian hàng
# replaced sử with sử sách
# replaced tiếp with giáp với
# replaced tiếp with tiếp giáp với
# replaced phủ with bao xung quanh
# replaced mộng with giấc mộng
# replaced gian with quầy
# replaced Trung with sông Trung
# replaced nuốt with nuốt chửng
# replaced tiếp with giáp với
# replaced gian with quầy hàng
# replaced Trung with sông Trung
# replaced nuốt with nuốt chửng
# replaced mộng with giấc mộng
# replaced sử with lịch sử
# replaced trâu with trâu sông
# replaced trâu with trâu sông
# replaced trâu with trâu nước
# replaced thằng with gã
# replaced thằng with lão
# replaced thằng with gã
# replaced chết with ngã xuống
# replaced chết with ngã xuống
# replaced chết with bỏ mạng
# replaced thành with bằng
# replaced trắng with màu trắng
# replaced xanh with chuyển thành xanh lam
# replaced thừa with dư thừa
# replaced thành with bằng
# replaced thừa with dư thừa
# replaced trắng with bạch
# replaced ấn with ấn vào
# replaced biến with thay đổi
# replaced trắng with bạch
# replaced nút with bít lại
# replaced thành with bằng
# replaced thức with không ngủ
# replaced thức with tỉnh
# replaced thức with tỉnh
# replaced đứng with theo như
# replaced thời with thời kì
# replaced gian with gian hàng
# replaced phát with cấp
# replaced chuẩn with tiêu chuẩn
# replaced cai with cai rượu
# replaced Thương with sông Thương
# replaced đô with nốt đô
# replaced gian with gian hàng
# replaced chuẩn with tiêu chuẩn
# replaced đứng with bám sát
# replaced đá with sút
# replaced Thương with sông Thương
# replaced hầu with cấp dưới
# replaced phát with phân phát
# replaced đứng with đứng trên
# replaced đầu with số 1
# replaced tóm with tóm cổ
# replaced Thương with sông Thương
# replaced thời with lúc
# replaced chuẩn with tiêu chuẩn
# generated augmented sentences with eda for /content/data_label_2.csv to /content/drive/MyDrive/new_dataset15.5/augmented_dataset_label_2_num8_0.15_wordnet.txt with num_aug=8

# %%
# Filter data that need to augment

# Filter label 1,2 - train on ViHSD dataset

# Dataset analysis
import pandas as pd

DATA = '/content/train.csv'
DATA_HATE = '/content/data_label_1.csv'

data = pd.read_csv(DATA, index_col=False)

#label0 = data.loc[data['label_id']==0]
label1 = data.loc[data['label_id']==1]
#label2 = data.loc[data['label_id']==2]

#data_new = pd.concat([label1, label2])
data_new = pd.concat([label1])

print(data_new)

data_new.to_csv(DATA_HATE, header=False, index=False, sep="|")
# Out:
#                                                free_text  label_id
# 7                                      Lúp lúp như chó .         1
# 18     Dạy bơi cho cá. Bơi thì đương nhiên nó bơi đượ...         1
# 38              Ý thức còn ít hơn cả số tiền trong túi t         1
# 47                                           xxx video 🔞         1
# 58                                 Đấu khẩu - Chim lợn 👍         1
# ...                                                  ...       ...
# 23990                                              Vcl ạ         1
# 23993                                     Cái đb gì vậy?         1
# 23994                                Nhìn gớm và tởm vậy         1
# 24027  Đéo thấy thằng nào bị tử hình... vì các nghìn ...         1
# 24029                                  Mất hình tượng vl         1
#
# [1606 rows x 2 columns]

# %% [markdown]
# HOW TO GET CC.VI.300

# %%
import gdown
import gzip

# Download the .gz file
gdown.download('https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.vi.300.vec.gz', '/content/cc.vi.300.vec.gz')

# Unzip the file
gzip.open('/content/cc.vi.300.vec.gz', 'r')
# Out:
# Downloading...
# From: https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.vi.300.vec.gz
# To: /content/cc.vi.300.vec.gz
# 100%|██████████| 1.24G/1.24G [00:47<00:00, 26.2MB/s]
# <gzip _io.BufferedReader name='/content/cc.vi.300.vec.gz' 0x7b338dff5930>

# %%
import gzip

with gzip.open('/content/cc.vi.300.vec.gz', 'rb') as f_in:
    with open('/content/cc.vi.300.vec', 'wb') as f_out:
        f_out.write(f_in.read())

# %% [markdown]
# **Fasttext**

# %%
# !pip install fasttext
# Out:
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.12.0-py3-none-any.whl (234 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.25.2)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4227140 sha256=425bf8eff936b54ca6048291eb2a59ea82f3291a6775d8a0dc717900997cf02b
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.2 pybind11-2.12.0

# %%
import gensim
model = gensim.models.KeyedVectors.load_word2vec_format('/content/cc.vi.300.vec',binary=False)

# %%
# TRAIN
# CODE augmetation: https://github.com/jasonwei20/eda_nlp

import random
from random import shuffle

random.seed(1)
import json

# import nltk

# nltk.download('wordnet')

class Argument:
    input = "/content/data_label_2.csv"
    output = "/content/drive/MyDrive/new_dataset15.5/augmented_dataset_label_2_num8_0.05_textfast.txt"
    num_aug = 8
    alpha = 0.05


args = Argument()

# stop words list
stop_words = []
# with open("drive/My Drive/CODE/HSD/vietnamese-stopwords-dash.txt", "r") as f:
#     stop_words = []
#     for line in f:
#         dd = line.strip('\n')
#         stop_words.append(dd)

# cleaning up text
import re


def get_only_chars(line):
    # clean_line = ""

    # line = line.replace("’", "")
    # line = line.replace("'", "")
    # line = line.replace("-", " ") #replace hyphens with spaces
    # line = line.replace("\t", " ")
    # line = line.replace("\n", " ")
    # line = line.lower()

    # for char in line:
    #     if char in 'qwertyuiopasdfghjklzxcvbnm ':
    #         clean_line += char
    #     else:
    #         clean_line += ' '

    # clean_line = re.sub(' +',' ',clean_line) #delete extra spaces
    # if clean_line[0] == ' ':
    #     clean_line = clean_line[1:]
    # return clean_line
    return line


########################################################################
# Synonym replacement
# Replace n words in the sentence with synonyms from wordnet
########################################################################

# for the first time you use wordnet
# import nltk
# nltk.download('wordnet')
from nltk.corpus import wordnet


def synonym_replacement(words, n):
    new_words = words.copy()
    random_word_list = list(set([word for word in words if word not in stop_words]))
    random.shuffle(random_word_list)
    num_replaced = 0
    for random_word in random_word_list:
        synonyms = get_synonyms(random_word)
        if len(synonyms) >= 1:
            synonym = random.choice(list(synonyms))
            new_words = [synonym if word == random_word else word for word in new_words]
            print("replaced", random_word, "with", synonym)
            num_replaced += 1
        if num_replaced >= n:  # only replace up to n words
            break

    # this is stupid but we need it, trust me
    sentence = ' '.join(new_words)
    new_words = sentence.split(' ')

    return new_words


# def get_synonyms(word):
# 	synonyms = set()
# 	for syn in wordnet.synsets(word):
# 		for l in syn.lemmas():
# 			synonym = l.name().replace("_", " ").replace("-", " ").lower()
# 			synonym = "".join([char for char in synonym if char in ' qwertyuiopasdfghjklzxcvbnm'])
# 			synonyms.add(synonym)
# 	if word in synonyms:
# 		synonyms.remove(word)
# 	return list(synonyms)

# def get_synonyms(word):
#     synonyms = set()
#     with open("drive/My Drive/CODE/HSD/word_net_vi.json", "r") as f:
#         wordnet = json.load(f)

#     for key, value in wordnet.items():
#         if key.strip() == word:
#             for v in value:
#                 synonyms.add(v.strip())

#         if word in synonyms:
#             synonyms.remove(word)
#     return list(synonyms)

def get_synonyms(word):
    synonyms = []
    sn = model.most_similar(word)

    for k in sn:
        synonyms.append(k[0])
    return synonyms


########################################################################
# Random deletion
# Randomly delete words from the sentence with probability p
########################################################################

def random_deletion(words, p):
    # obviously, if there's only one word, don't delete it
    if len(words) == 1:
        return words

    # randomly delete words with probability p
    new_words = []
    for word in words:
        r = random.uniform(0, 1)
        if r > p:
            new_words.append(word)

    # if you end up deleting all words, just return a random word
    if len(new_words) == 0:
        rand_int = random.randint(0, len(words) - 1)
        return [words[rand_int]]

    return new_words


########################################################################
# Random swap
# Randomly swap two words in the sentence n times
########################################################################

def random_swap(words, n):
    new_words = words.copy()
    for _ in range(n):
        if len(new_words) > 0:
            new_words = swap_word(new_words)
    return new_words


def swap_word(new_words):
    random_idx_1 = random.randint(0, len(new_words) - 1)
    random_idx_2 = random_idx_1
    counter = 0
    while random_idx_2 == random_idx_1:
        random_idx_2 = random.randint(0, len(new_words) - 1)
        counter += 1
        if counter > 3:
            return new_words
    new_words[random_idx_1], new_words[random_idx_2] = new_words[random_idx_2], new_words[random_idx_1]
    return new_words


########################################################################
# Random insertion
# Randomly insert n words into the sentence
########################################################################

def random_insertion(words, n):
    new_words = words.copy()
    for _ in range(n):
        add_word(new_words)
    return new_words


def add_word(new_words):
    synonyms = []
    counter = 0
    while len(synonyms) < 1 and len(new_words) > 0:
    # while len(synonyms) < 1:
        random_word = new_words[random.randint(0, len(new_words) - 1)]
        synonyms = get_synonyms(random_word)
        counter += 1
        if counter >= 10:
            return

    if len(new_words) > 0:
        random_synonym = synonyms[0]
        random_idx = random.randint(0, len(new_words) - 1)
        new_words.insert(random_idx, random_synonym)


########################################################################
# main data augmentation function
########################################################################

def eda(sentence, alpha_sr=0.1, alpha_ri=0.1, alpha_rs=0.1, p_rd=0.1, num_aug=9):
    sentence = get_only_chars(sentence)
    words = sentence.split(' ')
    words = [word for word in words if word is not '']
    num_words = len(words)

    augmented_sentences = []

    if len(words) <= 0:
        return augmented_sentences
    num_new_per_technique = int(num_aug / 4) + 1
    n_sr = max(1, int(alpha_sr * num_words))
    n_ri = max(1, int(alpha_ri * num_words))
    n_rs = max(1, int(alpha_rs * num_words))

    # sr
    for _ in range(num_new_per_technique):
        a_words = synonym_replacement(words, n_sr)
        augmented_sentences.append(' '.join(a_words))

    # ri
    for _ in range(num_new_per_technique):
        a_words = random_insertion(words, n_ri)
        augmented_sentences.append(' '.join(a_words))

    # rs
    for _ in range(num_new_per_technique):
        a_words = random_swap(words, n_rs)
        augmented_sentences.append(' '.join(a_words))

    # rd
    for _ in range(num_new_per_technique):
        a_words = random_deletion(words, p_rd)
        augmented_sentences.append(' '.join(a_words))

    augmented_sentences = list(set(augmented_sentences))
    augmented_sentences = [get_only_chars(sentence) for sentence in augmented_sentences]
    shuffle(augmented_sentences)

    # trim so that we have the desired number of augmented sentences
    if num_aug >= 1:
        augmented_sentences = augmented_sentences[:num_aug]
    else:
        keep_prob = num_aug / len(augmented_sentences)
        augmented_sentences = [s for s in augmented_sentences if random.uniform(0, 1) < keep_prob]

    # append the original sentence
    augmented_sentences.append(sentence)

    return augmented_sentences


# the output file
output = None
if args.output:
    output = args.output
else:
    from os.path import dirname, basename, join

    output = join(dirname(args.input), 'eda_' + basename(args.input))

# number of augmented sentences to generate per original sentence
num_aug = 9  # default
if args.num_aug:
    num_aug = args.num_aug

# how much to change each sentence
alpha = 0.1  # default
if args.alpha:
    alpha = args.alpha


# generate more data with standard augmentation
def gen_eda(train_orig, output_file, alpha, num_aug=9):
    try:
        writer = open(output_file, 'w')
        lines = open(train_orig, 'r').readlines()

        writer.write("free_text" + "," + "label_id" + '\n')
        augm = ""
        for i, line in enumerate(lines):
            try:
                parts = line[:-1].split('|')
                # print(parts)
                # sen_id = parts[0]
                label = parts[1]
                sentence = parts[0]
                aug_sentences = eda(sentence, alpha_sr=alpha, alpha_ri=alpha, alpha_rs=alpha, p_rd=alpha, num_aug=num_aug)
                for aug_sentence in aug_sentences:
                    # writer.write(label + "\t" + aug_sentence + '\n')
                    # writer.write(sen_id + "," +aug_sentence + "," + label + '\n')
                    augm = augm + aug_sentence + "," + label + '\n'
            except Exception as e:
                print(e)
                print(parts)
                pass

        writer.write(augm)
        writer.close()
        print(
            "generated augmented sentences with eda for " + train_orig + " to " + output_file + " with num_aug=" + str(
                num_aug))
    except Exception as e:
        raise e
        pass


# main function
if __name__ == "__main__":
    # generate augmented sentences and output into a new file
    gen_eda(args.input, args.output, alpha=alpha, num_aug=num_aug)
# Out:
# <>:212: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:212: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-5-4fdbb9e86ac8>:212: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   words = [word for word in words if word is not '']
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# replaced già with già
# "Key ':))' not present in vocabulary"
# ['ông già hay xaolon phết Tùng sói said :))', '2']
# "Key ':))))' not present in vocabulary"
# ['Hải Yến Đ care cmt làm gì??? :))) Ô ai hỏi m à? :))))', '2']
# replaced vs with Vs
# replaced về with vè
# replaced Đất with SétLễ
# replaced này with nào
# replaced đang with muốn
# replaced mẹ with bố
# replaced bạn with Hãy
# replaced ad with Dajla
# replaced 400 with 350
# "Key 'bài?' not present in vocabulary"
# ['Dlv bữa nay hoạt động về mặt kinh tế nữa à. Hay đi nhầm bài?', '2']
# replaced ông with Ông
# replaced ở with cả
# replaced coi with như
# replaced dao with rựa
# replaced ma with qủi
# replaced do with ,
# replaced thuyết with thuyê
# replaced phục with phuc
# replaced xl with lq
# replaced ủa with ừa
# "Key '😂' not present in vocabulary"
# ['My Trần ủa ụ á 😂', '2']
# replaced chủ with Chủ
# replaced nhà with toà
# replaced chửi with Chửi
# replaced xạo with Bậy
# replaced Thái with Lan•
# replaced Trọng with Trọng
# replaced ra with mở
# replaced hút with hít
# replaced bán with Bán
# replaced chua with chuaNhư
# replaced roi with Moddergat
# replaced Con with ngoanCon
# replaced Bảo with Long
# replaced ci with uen
# replaced Bảo with Minh
# "Key 'l**' not present in vocabulary"
# ['Gia Bảo ci l**', '2']
# "Key '🤦' not present in vocabulary"
# ['Vũ Thanh Huyền chán vl câu mấy câu đầu chửi hay bao nhiêu thì câu cuối thối không kém 🤦 tiền người ta làm gì kệ mẹ người ta , núp gầm giường hay sao biết người ta không từ thiện . Mệt mỏi mấy nhà từ thiện online như này thật sự .', '2']
# replaced thì with nên
# replaced quyền with chủquyền
# replaced thì with rồi
# replaced còn with cũng
# replaced mấy with cái
# replaced ý with •—Góp
# replaced ơi with ôi
# replaced biết with chưa
# replaced ko with dc
# "Key 'Tạng.' not present in vocabulary"
# ['Hà Nội sẽ đc đổi tên thành tp Mao Trạch Đông, đg biên giới VN sẽ đc mở rộng ra tới Tây Tạng. Giải phóng Đài Loan sẽ là nhiệm vụ hàng đầu của nhân dân xhcn, đế quốc Mỹ và bọn tay sai sẽ phải cút khỏi biển đông và biển nam hải. Cùng với Thượng Hải, Bắc K', '2']
# replaced cha with mẹ
# replaced tâm with đótrung
# replaced các with mọi
# replaced cho with giúp
# replaced Mom with Bubu
# replaced nay with đến
# replaced tài with chínhbản
# replaced như with những
# replaced để with về
# replaced lỳ with ù
# "Key 'CS.' not present in vocabulary"
# ['Nên nhớ đất nước nầy, tài sản nầy là của dân tộc, nhân dân Viết Nam chứ không phải của cái đảng CS. Cái đảng nầy như cơ quan quản lý. Quản lý không xong thì để người khác quản lý chứ đừng lỳ cái mặt bám ghế làm cho đất nước ngày càng lụn bại tàn mạt. T', '2']
# replaced Vải with Polyeste
# replaced Vải with vải
# replaced Vải with Viscose
# replaced m with cm=
# replaced nhiên with nhiênkhông
# replaced tự with Tự
# 'Key \'""âm\' not present in vocabulary'
# ['"Tú ông ngu suẩn nhìn mặt và thái độ sặc mùi ""âm hộ"""', '2']
# replaced mày with nhướn
# replaced thằng with 2thằng
# "Key 'hủy' not present in vocabulary"
# ['hủy thằng bố mày ý :)) ngu', '2']
# replaced nhau with nhau​
# replaced chỉ with muốn
# replaced như with giống
# replaced Thị with 3Quý
# replaced cứt with chó
# replaced Thị with Diospyros
# replaced tui with Tui
# replaced tui with Tui
# replaced linh with tinhEye
# replaced suốt with qua
# replaced giáo with dụcTriết
# replaced giáo with dụcCon
# replaced kiều with Hoa
# replaced nhà with xây
# replaced người with làngười
# "Key 'này,' not present in vocabulary"
# ['Đmm chúng nó cứ giết người kiều này, có ngày người nhà người ta đánh bomm chết cha lũ bác sỹ như mày.!!!', '2']
# replaced đk with đký
# replaced ma with zút
# replaced co with Zrób
# replaced nghe with ngheĐể
# replaced làm with nên
# replaced đời with đâyyyyyyy
# "Key 'nói,' not present in vocabulary"
# ['Đừng nghe cộng sản nói, hãy nhìn cộng sản làm muôn đời vẫn không sai !', '2']
# replaced mong with muốnAi
# replaced muốn with đang
# replaced điều with chuyện
# replaced Chôn with Thịnh5Chôn
# replaced Chôn with 0-19-816280-4
# replaced sống with sốngở
# replaced gì with hề
# replaced yêu with yêuNếu
# replaced không with vẫn
# "Key 'nhung17' not present in vocabulary"
# ['Gửi con ml nhung17 nhé =)))', '2']
# replaced của with cuả
# replaced ko with đc
# replaced ko with kko
# "Key 'khóc,' not present in vocabulary"
# ['Thiếu! Ý thức của người VN quá yếu và quá kém. Giờ giấc cao su, cha chung ko ai khóc, thiếu tinh thần hợp tác...', '2']
# replaced bụng with Bụng
# replaced Chỉ with chỉ
# replaced cho with của
# replaced chết with chếtcủa
# replaced chết with chết=
# "Key 'đi:))' not present in vocabulary"
# ['Đcmm đi chết đi:))', '2']
# replaced kỷ with từthế
# "Key 'juventuts' not present in vocabulary"
# ['Dm! qua đợt dịch này thì thằng sống ích kỷ này chắc sớm gia nhập juventuts', '2']
# replaced đại with Đại
# replaced ngẹo with khịu
# replaced hạnh with phúc4
# replaced được with đuợc
# replaced đại with cường
# replaced vừa with nênquái
# replaced quần with mặc
# replaced cho with các
# replaced lên with đưa
# replaced con with cha
# replaced thầy with Thầy
# replaced Đụ with Địt
# replaced Thằng with «Thằng
# "Key 'điên.' not present in vocabulary"
# ['Thằng điên.', '2']
# replaced di with ɛnvɪ
# replaced loc with chon
# replaced muon with khong
# replaced Mày with Tao
# "Key ':))' not present in vocabulary"
# ['Mày ngu vừa thôi ad :))', '2']
# replaced dần with DORIC
# replaced răng with răng1
# replaced còn with thì
# "Key 'à?' not present in vocabulary"
# ['Con khỉ trần dần vẫn còn răng à?', '2']
# "Key 'điên...' not present in vocabulary"
# ['Như  một  Con  điên...', '2']
# replaced cúm with H7N9
# replaced nhiễm with nhiễmΊ
# replaced nào with này
# replaced chống with «chống
# replaced thánh with Tômasô
# replaced chết with giết
# replaced khẩu with Khẩu
# replaced thị with thườngHiển
# replaced đại with nhị
# replaced mẹ with Bố
# replaced ăn with ănn
# replaced cho with nên
# replaced mỗi with lần
# replaced . with VÀ
# replaced em with e
# replaced Thanh with XuânĐổ
# replaced phản with phảnđối
# replaced niên with niên—đây
# replaced phím with phím•
# replaced nội with thất–
# replaced giữa with Giữa
# "Key 'động.' not present in vocabulary"
# ['Thanh niên phân biệt vùng miền bàn phím vãi lồng. Giỏi thì ra hà nội kêu bắc kỳ giữa đường hoặc sài gòn kêu nam kỳ xem. Coi thử có đi răng hàm mặt chỉnh hình không. Đkm lũ phân biệt vùng miền. Đkm lũ phản động.', '2']
# replaced đảng with «Đảng
# replaced con with ngoanCon
# replaced con with chú
# "Key ':))))' not present in vocabulary"
# ['Tùng hỏng :))))', '2']
# replaced chỉ with nhưng
# replaced đến with trước
# replaced đến with tới
# replaced biết with thấy
# replaced lol with hehee
# replaced ko with Ko
# "Key 'Uầy,' not present in vocabulary"
# ['Uầy, thế mà có cái hội lúc nào cũng ngông ngóng cái lũ đu càng đó gửi tiền về đó, chậc chậc😞', '2']
# replaced cùng with các
# replaced Ciel with ロン・デイビス
# replaced phải with phải
# replaced tin with nói
# replaced sân with vường
# replaced ng with th
# "Key 'thôi.' not present in vocabulary"
# ['Ciel Phạm thôi b ơi nói mấy nhiều ng vẫn cố chấp thôi. Bản tính ích kỷ cùng chung dòng máu VN mà ăn thua sân si. Bm ngta luôn muốn cái nào tốt đẹp nhất, tin tưởng VN điều trị thì phải đưa về VN chứ sao', '2']
# replaced coi with cũng
# replaced ô with tôCảm
# replaced đứa with cháu
# replaced bắt with Bắt
# replaced có with ít
# replaced muốn with phải
# replaced con with cha
# replaced lồn with 346,753
# replaced con with Con
# replaced dlv with CsV
# replaced vào with khi
# replaced dlv with đẻng
# "Key 'lã...Ko' not present in vocabulary"
# ['Bán nước hoa 500k như nước lã...Ko thơm tho gì hết...like trim thì chửi mắn cha mẹ người ta.. giờ khóc rồi hả.  Nhân quả đó e ơi....Bán hàng thật đi...', '2']
# "Key ':))' not present in vocabulary"
# ['Mày chửi thì mày nhắn mẹ đi :)) xạo lồn', '2']
# replaced tin with nhắn
# replaced dk with dky
# replaced tin with nhắn
# replaced đi with cứ
# replaced đi with cứ
# replaced đi with rủ
# replaced phe with «đảng
# replaced compat with incompatable
# replaced Dũng with Doãn
# "Key ':v' not present in vocabulary"
# ['Mai Anh Tuân Mua được mấy cái siêu xe cho các con du học bên bển rồi :v', '2']
# replaced thuế with thuếThuế
# replaced cái with một
# replaced mình with gồng
# replaced quần with SaQuần
# replaced lạc with lac
# replaced nước with nướcCây
# replaced bị with vì
# replaced lẫn with với
# replaced lẫn with cùng
# "Key 'rồi....' not present in vocabulary"
# ['Cụ này vừa bị lẫn vừa bị hoang tưởng rồi....', '2']
# replaced đi with xa
# replaced mẹ with em
# replaced Đuổi with ĐuổiCô
# replaced ad with Ad
# "Key 'rồi,' not present in vocabulary"
# ['Các bạn đọc thông cảm bme của tg ad đi gặm xương rồi, k mang nó theo nên nó xàm lồn, ngồi liếm cứt của bọn Bốc Bãi Cứt ra ăn đấy', '2']
# replaced mẹ with vợ
# replaced kệ with gāthā
# replaced mày with tao
# replaced nó with là
# replaced nó with để
# replaced mẹ with đẻ
# replaced các with những
# replaced của with chính
# replaced bạn with Hãy
# replaced gì with ai
# replaced dơ with rếch
# replaced Hitler with A.Hitler
# "Key 'này,' not present in vocabulary"
# ['Ta ước gì có một lão Hitler tái sinh trên đất nước này, làm sạch hết lũ cặn bã dơ bẩn', '2']
# replaced Lại with nữa
# replaced 1 with 5
# replaced trang with KT02Khẩu
# "Key 'ag.' not present in vocabulary"
# ['Lại mọc thêm 1 trang của viẹt tân ag. Đkm bọn chó đẻ', '2']
# replaced đúng with đúngvà
# replaced cá with Chẽm
# replaced yêu with thươngyêu
# replaced cá with rôphi
# replaced Chửi with thềNGỒI
# replaced lon with Lon
# replaced là with đã
# replaced đạo with biểu​Lãnh
# replaced mới with cũng
# "Key ':))' not present in vocabulary"
# ['Nguyễn Hoàng Sâm lol sâm nôn link :))', '2']
# replaced kiều with Kiều
# replaced trâu with heo
# replaced bảo with nghĩ
# replaced vậy with thế
# replaced con with conCha
# replaced con with nuôi
# "Key 'chết.' not present in vocabulary"
# ['Bụng như con heo vậy mà bài đặt bán thuốc giảm cân. Uống đi rồi chết.', '2']
# replaced nhiều with cũng
# replaced nhiều with rất
# replaced lại with lại
# replaced hôi with mồ
# replaced Vừa with Lúc
# replaced Vừa with Nghĩ
# replaced toàn with quốc​
# replaced sức with sức
# replaced tội with phạmtội
# replaced . with …
# replaced Mũi with mủi
# replaced lan with bùng
# replaced thì with nếu
# replaced nghiệp with Nghiệp
# replaced Ở with Dù
# replaced có with hề
# replaced có with là
# replaced có with Có
# replaced Bố with Má
# replaced Kinh with 。Kinh
# replaced Thần with «Thần
# replaced xài with BB9700
# replaced này with này
# replaced trùng with tiệt
# replaced rồi with nữa
# replaced mới with mới
# replaced bộ with 88-6307
# replaced tháng with tháng10
# replaced tháng with 01tháng
# replaced lấy with lấy
# replaced kia with cạnh
# replaced là with và
# replaced kia with cạnh
# replaced đúng with vậy
# replaced là with mà
# replaced đúng with thì
# replaced nay with nhưng
# replaced ghe with Ghe
# replaced nhin with hi`nh
# replaced Non with NHMS
# replaced ơi with ơiiii
# replaced Non with NHMS
# replaced dỏm with dổm
# replaced mắt with tròng
# replaced đảo with Đảo
# replaced chửi with chửi
# replaced thẳng with phía
# "Key 'nhé!' not present in vocabulary"
# ['Đm chú chửi ai thế? Mai nghỉ việc cho đỡ căng thẳng nhé!', '2']
# replaced ưa with hễ
# replaced bù with EnerluxTụ
# replaced củng with đuợc
# replaced sản with xuấtt
# replaced Đỉnh with Puvan
# replaced Đỉnh with 3Đỉnh
# replaced đẹp with Dáng
# replaced đúng with là
# replaced ai with gì
# replaced no with Fuuin
# replaced be with To
# replaced Sài with 70138
# replaced gì with là
# replaced cũng with biết
# replaced đâu with chẳng
# replaced hết with mất
# replaced đúng with đúngvà
# replaced tiền with tiềnNếu
# replaced Dit with KENCH–
# replaced cai with Cai
# replaced me with sabbo
# "Key 'di.' not present in vocabulary"
# ['Dit me cai quy trinh,vao cap cuu deo co tien,deo bao hiem thi nam do di.', '2']
# replaced sinh with sinhđến
# replaced như with những
# replaced to with be
# replaced vãi with ghê
# replaced khôn with Khôn
# replaced vãi with voãi
# replaced nó with sẽ
# replaced cho with khiến
# replaced cho with nên
# replaced phủ with Phủ
# "Key '😂' not present in vocabulary"
# ['Em mà đập đc thằng chính phủ như vậy chắc e đã làm rồi 😂', '2']
# replaced dễ with ợt
# "Key 'thương.' not present in vocabulary"
# ['Kệ mẹ lồi báo, bé này dễ thương.', '2']
# replaced Bóng with đènBóng
# replaced vàng with vàngLá
# replaced vàng with vànglà
# replaced page with page»
# "Key ':))))' not present in vocabulary"
# ['qua page Comcom xem dân VN cũng có nhiều thằng ngu tương tự đó :))))', '2']
# replaced đầu with trong
# replaced í with àh
# replaced đầu with trước
# "Key 'ái.' not present in vocabulary"
# ['Nói í thức như đầu buooi thì lại tự ái.', '2']
# replaced mà with sẽ
# replaced bọn with Đám
# replaced láo with phịa
# replaced sẽ with và
# replaced đêm with khuya
# replaced đến with tới
# "Key 'sinh🙃' not present in vocabulary"
# ['Em sẽ đến đơm cái lỗ nhị thầy đêm giáng sinh🙃', '2']
# replaced danh with danhGhi
# replaced biết with không
# replaced đã with có
# replaced Vũ with Tú
# replaced giá with giá
# replaced trị with bệnhChữa
# replaced co with Co
# replaced oi with jup
# replaced chet with ngap
# replaced nhiều with cũng
# replaced án with 2Dự
# replaced 20k with 10k
# replaced giả with Giả
# replaced nhé with đấy
# replaced khịa with kẹc
# replaced Chị with Mai
# replaced đức with phật»
# replaced đâu with nào
# "Key 'đảng,' not present in vocabulary"
# ['Cộng sản toàn lũ tư tưởng độc đảng, Qua bên mĩ còn tư tưởng độc đảng như CHINA', '2']
# replaced bằng with hoặc
# replaced thể with thaoChế
# replaced không with còn
# replaced sự with đã
# replaced thể with thao40
# replaced chả with chứ
# replaced thôi with Chứ
# replaced thôi with rồi
# replaced dân with nướcngười
# replaced thầy with thầyCó
# replaced lol with heheee
# replaced lol with LOL
# "Key '🤤' not present in vocabulary"
# ['Fan cứng dạo hả thầy lol 🤤', '2']
# replaced hoàng with đoàng
# replaced điên with điêndÔi
# replaced mấy with mươi
# replaced hồi with なんじ：mấy
# replaced phim with phimĐây
# replaced trời with Trời
# replaced bình with bình–
# replaced thần with thầnĐẳng
# "Key 'hóa' not present in vocabulary"
# ['Ns cái quái j vậy trời ... tưởng mình là hoàng thân quốc thích của bên tàu bên mĩ j còn tồn tại hay sao ak... hay là coi mấy cái phim rồi lên cơn sản.người nhà đưa ra nước ngoài điều trị tâm thần.. mong chú sớm bình phục rồi chở lại đúng con người của mình .đừng thần tượng mấy ông công công hồi đó rồi hóa điên hóa khùng ...', '2']
# replaced háng with cặc
# replaced Ngọc with Linh
# replaced cây with trồng
# replaced kiết with bống
# replaced gió with gió
# replaced gió with gióHôm
# replaced buồn with buồnCó
# replaced buồn with buồnMà
# replaced chị with Chị
# replaced dân with người
# "Key 'quốc.đến' not present in vocabulary"
# ['Nhục cho bạn này là con dân nước Việt ...đang góp phần chia re.thuần hoá dân tộc.và thủ tục dân nước cho bọn trung quốc.đến khi mất nước vào tay bọn tq thì nó là tội nhân thiên cổ', '2']
# replaced mẹ with bà
# replaced chúng with nếu
# replaced mày with nhướn
# replaced sau with đằng
# replaced qua with trải
# replaced oi with gia`
# replaced thầy with thầycô
# replaced thầy with côThầy
# replaced Dạng with dạng
# replaced a with O.n
# replaced ấy with ta
# replaced ấy with Cô
# "Key 'ơi.' not present in vocabulary"
# ['Đúng tính cách a ấy luôn bây ơi. Loài hợp quần', '2']
# replaced thì with cũng
# replaced 700 with 400
# replaced 700 with 800
# replaced mà with nó
# replaced Cứ with Vì
# replaced chửi with chưỡi
# replaced đòi with lại
# replaced lại with nhưng
# replaced các with trong
# "Key 'coi..' not present in vocabulary"
# ['Vô liêm sỉ. Dối trá. Tàn độc mà đòi chổ tựa của văn minh sao? Tìm lại các câu nói của đảng viên coi..', '2']
# replaced khi with thì
# "Key 'gì.' not present in vocabulary"
# ['Trần Thị Ngọc Anh hơn giống loài tỏ ra thượng đẳng trong khi chả biết củ lìn gì.', '2']
# replaced cc with clgv
# replaced tao with mày
# replaced ne with iy
# "Key 'Tich.' not present in vocabulary"
# ['cc ne Chu Tich. Phạt tao đi.', '2']
# replaced so with s¸nh
# replaced nhe with nha...hehe
# replaced ky with Ky
# replaced lon with guigoz
# replaced em with ko
# replaced lon with caidong
# "Key '=]]' not present in vocabulary"
# ['Con bóng sadec =]]', '2']
# replaced đá with ñá
# replaced đá with gỗ
# replaced đi with rủ
# replaced còn with lại
# replaced dê with sồm
# replaced gà with rôti
# replaced bạn with Nếu
# replaced cái with mấy
# replaced à with hả
# replaced mà with Vì
# replaced của with riêng
# replaced giỏi with Giỏi
# replaced của with cảu
# replaced cáo with Cáo
# replaced dân with toàn
# "Key 'dcm=))' not present in vocabulary"
# ['Đồ Uyển Đình Ngọc dcm=)) chai sting vô đầu nha', '2']
# replaced t with th
# replaced vãi with shit
# replaced về with vè
# replaced đó with mà
# replaced mới with được
# replaced đó with ấy
# replaced ngọc with TỪngọc
# replaced thề with Thề
# replaced mặt with nhìn
# replaced hành with tinhTự
# replaced Thi with thi
# replaced thì with rồi
# replaced TC with UBTH
# replaced TC with 62-85
# replaced tội with phạmTrinh
# replaced này with cũng
# replaced chống with thấmChống
# replaced nước with nươc
# replaced ngon with ngonSự
# replaced ngon with ngonXôi
# replaced có with sẽ
# replaced bệnh with bệnh–
# replaced ngu with deibet88tai
# replaced bị with mà
# replaced lóc with Khứa
# replaced lại with cho
# replaced líp with líp
# replaced lòng with lòngNụ
# replaced chắc with thì
# replaced là with và
# replaced Sai with Veun
# replaced Đấy with Chắc
# replaced cha with đâubạn
# "Key 'nhé.' not present in vocabulary"
# ['Đấy thế nhé. Thế là vừa lòng nhé. Chưa kể những ng kêu là không ngại nguy hiểm kia toàn là lính. Sai đâu đánh đó. Không kêu chắc tự ra làm. Mà nói là nói mấy cha bụng bự kia chứ nói gì lính lác.', '2']
# replaced vi with phạp
# replaced đúng with đúngvà
# replaced biệt with Nhi�
# replaced Loại with khácKiểu
# replaced viễn with viễn20
# replaced này with nhưng
# replaced bài with thơ
# replaced này with của
# replaced hay with cũng
# replaced lính with lính–
# replaced Tại with tại
# replaced cả with ba
# replaced mày with Mày
# replaced cái with hai
# replaced cái with mấy
# replaced nó with ko
# replaced đỏ with màu
# replaced cái with những
# replaced mẹ with mẹKhi
# replaced Kệ with A.KTV
# replaced mày with mầy
# replaced LÝ with bùnXỬ
# replaced kiểu with giống
# replaced mẹ with Mẹ
# replaced được with lại
# replaced chứ with Chứ
# "Key 'gì.' not present in vocabulary"
# ['Vậy trả thuế lại cho dân đi dân nó tự chống. Mọe làm không được chứ gì. Nói mẹ là cán dọng hết rồi nên làm gì còn mà trả. NGU', '2']
# replaced Việt with ViệtMỹ
# replaced Nam with Đông
# replaced ly with hônTim
# "Key 'nhà,' not present in vocabulary"
# ['N17 khai gian dối, lây lan cho người nhà, hại bao nhiêu ng Việt Nam bị cách ly nên bị mọi người chửi là đúng.', '2']
# replaced ra with tỏ
# replaced việc with phải
# replaced bố with bà
# replaced hồi with năm
# replaced sống with sốngở
# replaced thứ with ngày
# replaced ra with đã
# replaced mấy with mươi
# replaced ý with lênLưu
# replaced năng with •Chức
# replaced ko with Nhg
# replaced che with Che
# replaced khung with câykhung
# replaced dam with damgai
# replaced het with dau`
# replaced nhai with gặm
# replaced mẹ with vợ
# replaced Nhok with Nhok™
# "Key 'hóa' not present in vocabulary"
# ['Bạn chả có máu hóa văn loz j cã=]]', '2']
# replaced nữa with chứ
# replaced bậy with đái
# replaced Mày with mầy
# replaced ơi with ơiii
# replaced như with hệt
# replaced Trung with Quốc143669
# replaced mặt with Mặt
# "Key '?????' not present in vocabulary"
# ['Nếu bảo chủ tịch mặt như l... thì ?????', '2']
# replaced người with nguời
# replaced Sườn with 1Thịt
# replaced nên with phải
# replaced ghê with lém
# replaced Con with Thằng
# replaced Con with Chú
# replaced dam with kiếmxnxx
# replaced luon with roi`
# replaced cham with soc
# replaced kidz with ​​biển
# replaced khả with thể
# replaced xin with gởi
# replaced lồn with lồn
# replaced clear with clear=
# replaced vs with nc
# "Key 'sbtc' not present in vocabulary"
# ['"Ko phải chê gì chứ khả năng win của sbtc quá cao. Sela kidz clear vs petland toàn những thanh niên chuyên nghiệp try hard vkl sao những ""ông già"" bên kia chơi lại. Còn thầy lồn thì t xin mạng phép bỏ qua ko nói tới coi như sbtc 4 đánh 6"', '2']
# replaced cá with bớp
# replaced cái with kia
# replaced linh with tinhLều
# replaced mình with mìnhđang
# replaced ng with ườ
# replaced gì with ấy
# replaced dlv with DLV
# replaced Tao with mày
# replaced báo with Enquirer
# "Key '😂😂😂' not present in vocabulary"
# ['Tao báo dlv 😂😂😂', '2']
# replaced trâu with trâuĐể
# replaced Ai with dè
# replaced lịch with Lịch
# replaced tức with thuộcTin
# replaced tưởng with ngờ
# replaced tin with nhữngthông
# replaced đc with dc
# replaced đc with tnào
# replaced Và with vì
# replaced kịp with kịp
# replaced vậy with thôi
# replaced buổi with buổi
# replaced bộ with đồ
# replaced xin with muốnđược
# replaced Lên with LênXuống
# replaced dựg with zựng
# replaced cấm with việc
# replaced chính with này
# replaced về with ,
# "Key 'nhé.' not present in vocabulary"
# ['Chịu khó đọc báo dùm. Tiền xây tượng do dân địa phương đóng góp. Nguyên nhân tháo dở là do xây dựg ko xin phép cơ quan sở tại. Vải lại đag trong quá trình xây dựng nhé. Ko lẻ mấy lủ ngu các người xây nhà kiểu Âu Mỹ mà ko xin phép, bị cơ quan thẩm quyền tháo dở. Lủ ngu lại riêu rao: Do xây nhà theo kiểu tư bản nên bị chính quyền ngăn cấm àk? Lên mạng chi mà ko khôn ra được, thằng ad page này có vấn đề về nảo bộ', '2']
# replaced nay with đến
# replaced mua with tặng
# replaced Sau with Trong
# replaced Đố with ai
# replaced tên with Tên
# replaced tên with xưng
# replaced Ly with ly
# replaced Lol with noob
# replaced kêu with gào
# replaced nói with cũng
# "Key 'ckx' not present in vocabulary"
# ['Bóng già nói ckx nge muốn xỉu', '2']
# replaced nhân with nhânHạnh
# "Key 'trị,' not present in vocabulary"
# ['Về chính trị, chúng tuyệt đối không cho nhân dân ta một chút tự do dân chủ nào.', '2']
# replaced được with nhưng
# replaced gọi with nhấc
# replaced Sài with Gòn3
# replaced hát with nhạcc
# replaced c with iệ
# replaced vàng with bạc
# replaced Hazardous with https://www.epa.gov/haps/health-effects-notebook-hazardous-air-pollutants
# replaced sủa with Sủa
# replaced vô with dzô
# replaced ý with bảnGóp
# replaced thức with dậy
# replaced Mình with MÌnh
# replaced phới with luxor
# replaced phới with Phơi
# replaced diễn with biễu
# "Key 'khác.' not present in vocabulary"
# ['Trong một diễn biến khác. Lại có cờ mẫu quốc phấp phới đâu đây', '2']
# replaced giống with làgiống
# replaced thế with chứ
# replaced đến with nay
# replaced để with đã
# replaced này with mới
# replaced gì with ?
# replaced đá with gỗ
# replaced bú with mẹ
# replaced bú with mẹ
# replaced mệt with nhọc
# replaced quỷ with Kamát
# replaced nghe with nói
# replaced đâu with biết
# replaced giẻ with Giẻ
# replaced Ba with Cả
# replaced con with ngườicon
# replaced củ with đậmRau
# replaced đc with dc
# "Key 'đ'' not present in vocabulary"
# ["Sủa như chó đc 3 củ còn đ' đủ ăn cơm, bọn kia đ' làm gì vẫn đc đi định cư :v đúng là kiếp con bò", '2']
# replaced cộng with củacộng
# replaced cộng with củacộng
# replaced Địt with Lồn
# replaced nhiễm with nhiếm
# replaced bóng with bóngtối
# replaced trụi with cành
# replaced nhiễm with nhiễmô
# replaced luôn with phải
# replaced thì with phải
# replaced luôn with luônluôn
# replaced chả with Chả
# replaced yếu with tgm
# "Key 'lệ,' not present in vocabulary"
# ['Khi sự thật nó trần trụi thì chả con bò nào chịu như thế cả. Tư duy chỉ cần thắng bóng đá còn nô lệ, ô nhiễm chết lần chết mòn, dân tộc suy vong thì mặc kệ. Chính điểm yếu này mà tầng lớp thanh niên VN bị CS dắt mũi như những con lừa chỉ bằng vài trận bóng. Sự Thật luôn nghịch nhĩ.', '2']
# replaced mạch with mạchKỹ
# replaced sạch with sạchĐể
# replaced để with Ðể
# 'Key \'""\' not present in vocabulary'
# ['"Đéo biết gì thi ngồi im . chỗ đấy có long mạch của đất nước đấy "" chuẩn bị đầu tư 20 tỷ để vét máng cho sạch đó "" :)))))."', '2']
# replaced ở with là
# replaced tù with Oẳn
# "Key 'xaolol' not present in vocabulary"
# ['Về nước a nên vào tù ở trước thay vì gặp người khác xaolol', '2']
# replaced bỏ with đi
# replaced chính with cũng
# replaced quyền with „quyền
# replaced đừng with bạnđừng
# replaced nói with hiểu
# replaced hả with ạ
# replaced ta with đó
# replaced nói with rằng
# replaced gì with Có
# replaced vun with Vun
# replaced vo with gạoMẹo
# replaced mà with sẽ
# replaced cũng with biết
# replaced tung with hoành
# replaced như with những
# replaced Tẩy with 4200Pad
# replaced Tẩy with Waxing
# replaced con with conCòn
# replaced lãnh with đạoVì
# replaced nó with Nó
# replaced con with Con
# replaced co with Zrób
# replaced hang with hangquay
# "Key 'ho..chj' not present in vocabulary"
# ['Quan chuc nha nc lam gi co tien ung ho..chj co tien chon duoi dat thoi...ko gjam gui ngan hang so bj lô.😂😂', '2']
# replaced nàn with Başbereket
# replaced bị with sợ
# replaced 1 with 9
# replaced cộng with «cộng
# replaced sẽ with có
# replaced Trần with T.Linh
# replaced lệ with khệ
# replaced nghịch with thiên
# replaced toàn with Toàn
# replaced Thầy with thầyThầy
# replaced thầy with thầythưa
# replaced thầy with thầyCó
# replaced nói with hỏi
# replaced xấu with xấu
# replaced mà with sẽ
# replaced luật with luậtPháp
# replaced cả with và
# replaced cả with ở
# "Key 'Caiditmemay' not present in vocabulary"
# ['Caiditmemay', '2']
# list index out of range
# ['"Tan Levan Vì chúng ta ăn bám. Phá hoại nước mỹ. Chúng ta làm sấu mặt nước mỹ gần 50 năm.']
# replaced chán with thèm
# replaced mỹ with miều
# replaced nó with họ
# 'Key \'thôi."\' not present in vocabulary'
# ['Nên mỹ chán nó bỏ thôi."', '2']
# replaced này with nhưng
# replaced con with đứa
# replaced mặt with mắt
# replaced được with làm
# replaced Mỹ with Mĩ
# replaced ra with mà
# replaced nho with Jabuticaba
# replaced vay with lãi
# replaced ba with Ba
# replaced bận with trễ
# "Key 'đâu,' not present in vocabulary"
# ['Lũ bán nước thì đang bận bán nước chớ đâu, hỏi cái lồn !', '2']
# replaced ngu with xuẫn
# replaced thằng with Thằng
# replaced 1 with 5
# "Key 'việc..dm' not present in vocabulary"
# ['Mỗi người 1 công việc..dm thằng đăng bài ngu đéo chịu đc', '2']
# replaced dơ with bẩn
# replaced chứ with nhỉ
# replaced nhận with trả
# replaced hư with hỏng
# replaced dựng with mớiXây
# "Key 'phím.còn' not present in vocabulary"
# ['Trần Thị Ngọc Anh t chỉ nói k biết thực hư thế nào thì đừng cào phím.còn t cmt cho vui thôi.động gì đến mồ mả nhà bạn đâu mà dựng lông lên thế.', '2']
# replaced mocphin with Nalorphin
# "Key 'quơn-cấp' not present in vocabulary"
# ['năm nay đông lào chắc vào tận chung kết quơn-cấp mới mong đủ liều mocphin cho lũ cừu cáo ngơ !', '2']
# "Key 'CHỔNG' not present in vocabulary"
# ['Huỳnh Chí Tính CLMM CHỔNG MÔNG LÊN', '2']
# replaced thiết with kếNội
# replaced hoàn with hảoNếu
# replaced thầy with thầyThầy
# replaced thành with chia
# replaced phần with phần
# replaced hết with thì
# replaced đã with vì
# replaced sau with ngay
# replaced vay with vốn
# replaced nhận with đươc
# replaced chịu with nổi
# replaced và with ,
# replaced không with chưa
# replaced ngồi with ngồiSố
# replaced họ with ấy
# "Key 'đi,' not present in vocabulary"
# ['Mấy đứa ngồi hóng đi, anh sẽ tận thu tận gốc và chúng mày phải chịu cho điều đó, tất cả vì con cái và dòng họ của tao nghe chưa... thằng nào không chấp nhận tao cho Ung thư và tai nạn hết....', '2']
# replaced phần with một
# replaced Chung with HescoChung
# replaced Chung with N.Chung
# replaced mẹ with Bà
# replaced a with 2ab
# replaced mẹ with mẹKhi
# replaced Việt with NamDù
# replaced trung with Trung
# replaced đỏ with booc
# replaced vô with NhiÖm
# replaced việc with Việc
# replaced vậy with đâu
# "Key 'chủ,' not present in vocabulary"
# ['Cái bọn bang đảng búa liềm này rất láo, vô sỉ. Miệng thì bù lu bù loa dân làm chủ, nhà nước quản, can bộ là đầy tớ nhưng xin hỏi có thằng đầy tớ nào mà láo như vậy ko, ko hề trình báo công việc mình làm, tiến trình và kết quả ra sao cho chủ, lại giữ bí', '2']
# replaced dị with lạ
# replaced đách with đék
# replaced đó with họ
# "Key 'Abe:)' not present in vocabulary"
# ['hát như cái đách lồn dị đó Abe:)', '2']
# replaced ăn with bưã
# replaced là with có
# replaced là with Đó
# replaced be with Bup
# replaced nghiep with nghieptai
# replaced thu with nộp
# replaced đó with ,
# replaced đó with nó
# replaced nhân with BoYkUtENguyên
# replaced mày with mầy
# replaced page with flypage
# "Key 'Lồn.' not present in vocabulary"
# ['Kệ mẹ người ta đi, ăn mã cha của mày hả page Lồn.', '2']
# replaced post with reupload
# replaced toàn with Toàn
# replaced này with khác
# replaced loạn with đổiRối
# replaced đc with Nhg
# replaced viên with kếNhân
# replaced nào with nào
# replaced nhắc with nhắcnhở
# replaced thuê with thuêDT
# replaced kinh with doanhD
# replaced cấm with कश्चिद्धर्मो
# replaced tao with antwuan
# replaced như with trong
# replaced c with iệ
# replaced con with đứa
# replaced đu with N.Ma
# replaced roi with sảnQuả
# "Key 'bay.' not present in vocabulary"
# ['Nguoi ta chuyen gioi rôi. No lam lôn roi đê đu thăng cha tyi bay.', '2']
# replaced đứa with con
# replaced mà with và
# replaced hâm with tiệt
# replaced đẻ with gà
# replaced con with cha
# replaced cũng with được
# replaced đã with và
# replaced nghe with nói
# "Key 'rồi.' not present in vocabulary"
# ['Đấy nghe chưa. Quốc sư nói Mỹ đã xóa cờ hó VNCH lâu rồi.', '2']
# replaced hiểm with hiểm7
# replaced mình with chính
# "Key 'vcl:))' not present in vocabulary"
# ['Đm admin ngu vcl:)) chăcs cậu đang tưởng mình hay vs nguy hiểm lắm đấy:))', '2']
# replaced con with conCòn
# replaced quan with trọngtrong
# replaced trụ with Trụ
# replaced phét with „MLC
# replaced nhiều with rất
# replaced giáo with dụcCon
# replaced mà with đó
# replaced Thầy with „Thầy
# replaced muốn with làm
# "Key ':))' not present in vocabulary"
# ['Hài vcl. Buồn mà xem video của Thầy là muốn tự tử :))', '2']
# replaced Con with Mày
# replaced kinh with doanhVốn
# replaced Con with Thằng
# replaced Ngu with yễn
# replaced Ngu with keytar
# replaced Ngu with D46
# replaced tầm with 08320
# replaced Dăm with Róc
# replaced thăng with thăng%
# "Key 'này...' not present in vocabulary"
# ['Mikaela Hyakuya chủ tịch cái vẹo gì tầm này... Đinh la thăng còn hẹo... Dăm ba thằng chủ tịch ghẻ', '2']
# replaced Người with ——Người
# replaced sản with xuấtts
# replaced cộng with trừ
# replaced nhưng with không
# replaced cô with vợ
# replaced ai with Ai
# replaced thì with phải
# replaced chạm with tay
# "Key 'ok,' not present in vocabulary"
# ['@Hoàng Phúc Lê t củng đã cmt gì trên fb bả đâu mà bị chửi chỉ là đọc thấy ko thích ok, m ko đọc là t củng thích xem clip vì vui nhưng đọc cmt thì thấy nhiều cái quá đáng à chứ t chửi gì cô lan của m. Lgbt tối ngày đòi bình đẳng ko kì thị nhưng người ta chưa nói động chạm gì mà dựng lồn lên chửi như m thì người ta ai ko ghét 🙂', '2']
# replaced Bố with Má
# replaced bà with cô
# replaced Bố with bố
# replaced làm with phải
# replaced cuồng with phát
# replaced dục with Bachíniva
# replaced kéo with trút
# replaced đẹp with Đẹp
# replaced đẹp with đẹpby
# replaced chửi with chưởi
# replaced made with wortelvlieg
# replaced hết with hết
# replaced Thuận with Hưng
# replaced sáng with rạng
# replaced nhà with vườn
# replaced khổ with 10x15cm
# replaced phải with muốn
# replaced các with nhiều
# "Key '🙂' not present in vocabulary"
# ['nếu nó khai báo cẩn thận thì cả máy bay bị cách ly ngay từ đầu thì có phải giờ đỡ khổ không. Chúng ta đéo nên bênh các bạn ơi 🙂', '2']
# replaced gì with mà
# replaced cũng with còn
# replaced xàm with moá
# replaced trả with chuộc
# replaced tới with gần
# replaced biểu with Biểu
# replaced con with cha
# replaced con with conCòn
# replaced dai with dẳng27
# replaced mỗi with chục
# replaced tỷ with triệu
# replaced ấy with họ
# "Key 'nó.' not present in vocabulary"
# ['Nghe đâu mỗi năm mất gần hơn 900 tỷ để duy trì cái xác ấy sống mãi trong sự nghiệp cướp bóc của chúng nó. Kinh , xác cha già chúng nó mà chúng nó cũng ko tha, xơi luôn.Bao nhiêu năm rồi nhỉ?!', '2']
# replaced Anh with Ạnh
# replaced đó with Đó
# replaced đó with Đó
# replaced cmt with comt
# replaced cmt with post
# replaced đi with rủ
# replaced đến with đên
# replaced Tội with nghịp
# replaced lại with mang
# replaced hình with chụp
# replaced quyền with „quyền
# replaced múa with bale
# replaced lâm with ngưngư
# replaced mây with hạVắt
# replaced ngon with ngon5
# replaced đường with mộtđường
# "Key 'cs!' not present in vocabulary"
# ['Thiên đường của cs!', '2']
# replaced này with nào
# replaced sĩ with 648Bác
# replaced vcl with shjt
# "Key ',thưởng' not present in vocabulary"
# ['Ơ cái địt con mẹ con Vj Chon lon nào vào sủa cái câu ngu ngục vcl =))) mục đích ca sĩ ra bài là để cho khán giả nghe ,thưởng thức. Và các khán giả có quyền nhân xét về sản phẩm đó ? Lại là mấy con fans hâm mộ trẩu tre này', '2']
# replaced du with 少年游
# replaced tốn with tiền
# replaced học with trường
# replaced giặc with nữathôi
# replaced bưng with múc
# replaced đu with mấmát
# "Key 'nhủng.' not present in vocabulary"
# ['Thật ra: đu càng tốn cả triệu đô. Chỉ có ở bọn CS quan lớn tham nhủng. Đưa gđình và con cái du học định cư sung sướng. Chứ bò đỏ umê bưng bô làm gì có cửa đu. Chỉ biết làm con chốt thí cho giặc tàu.. ha ha', '2']
# replaced thì with nếu
# replaced báo with Enquirer
# replaced toàn with quốcGói
# replaced tư with duyĐề
# replaced Ổng with Mầy
# replaced r with n
# replaced như with cũng
# replaced cứt with kứt
# replaced cứ with Cứ
# replaced óc with chóQuả
# replaced Trần with Lý–Trần
# replaced Sang with 2Sang
# replaced thấy with nghĩ
# replaced Chưa with ​Chưa
# replaced như with trong
# replaced thật with rất
# replaced Abe with 9M113M
# "Key ';v' not present in vocabulary"
# ['Abe đúng là thật xàm l ;v', '2']
# replaced cô with em
# replaced này with mới
# replaced ng with t
# replaced Anh with Scotland
# replaced phải with thì
# replaced bày with nhàTrình
# replaced đó with nó
# replaced ta with ai
# replaced Còn with Chứ
# replaced Bạn with hoặc
# replaced bè with đỡBạn
# replaced còn with nhưng
# "Key ':)' not present in vocabulary"
# ['Bạn bè mà 1 người có ý thức còn 1 ng thì....ý thức nhỏ như trái nho :)', '2']
# replaced hơi with không
# replaced mừg with zốg
# replaced to with cỡ
# replaced 3 with 9
# replaced giong with bai`
# replaced mac with Cináed
# replaced trung with Trung
# replaced a with тиква
# replaced thằng with thèng
# replaced thì with cũng
# replaced còn with vẫn
# replaced ? with ah
# replaced Linh with Huyền
# replaced me with sabbo
# replaced nguoi with moinguoi
# replaced vấn with đíchTư
# replaced Cố with Mộ
# replaced đàn with Đàn
# list index out of range
# ['"NGUYỄN Anh Tuấn “ Dạ ...Trần Dần là 3/// nhưng mà que đã què nen không còn khả năng xỏ lá nữa  chỉ cái tội bị mắc đường bố nói xàm mà thôi 😁😀🤓”']
# list index out of range
# ['Mỗi khi thấy lão tôi không thể chửi nửa .............mà chỉ cười tét rốn']
# list index out of range
# ['Vì coi như xem hài miễn phí vậy mà']
# 'Key \'😂🤣"\' not present in vocabulary'
# ['😂🤣"', '2']
# replaced chất with chấtt
# "Key '😏' not present in vocabulary"
# ['Con Linh nó vẫn chứng nào tật nấy . Vì bản chất của nó là vậy. 😏', '2']
# replaced tên with đặt
# replaced mà with Mà
# replaced tên with Tên
# replaced ngta with ...ko
# replaced dâm with đãngHD
# "Key 'à.' not present in vocabulary"
# ['Ủa nó tưởng đăng facebook là ghê gớm hả ta, đăng lên cho ngta chửi thêm à. Đề nghị mọi người unfollow face nó để nó đăng lên rồi tự thủ dâm lấy.', '2']
# replaced linh with linhỞ
# replaced di with Iorio
# replaced loc with lọc
# replaced mù with Còi=chỵ
# replaced dân with người
# replaced quân with quân»
# replaced điếc with ngọng
# replaced ANH with DŨNG
# replaced điếc with EMM2023MW
# replaced người with Người
# replaced thích with thíchBạn
# replaced cho with giúp
# "Key 'Lmcs' not present in vocabulary"
# ['Lmcs', '2']
# replaced nhu with �áng
# replaced ng with êi
# replaced Dung with Loan
# replaced và with mà
# replaced và with về
# replaced chẳng with không
# replaced du with Sautoy
# replaced Sao with Thì
# replaced mieng with Mieng
# "Key 'vay.' not present in vocabulary"
# ['Sao cai mieng no xau du vay.', '2']
# replaced tài with chínhl
# replaced chó with samoyed
# replaced chó with becgiê
# replaced 2 with 3
# replaced ngta with nhg
# replaced ngta with ...ko
# "Key 'Do.' not present in vocabulary"
# ['Con.   Quy.  Nãy. Cái.   Miệng.   Nó.  Thúi.  Quá.  Đồ.  Do.   Bán.', '2']
# replaced Ăn with ​Ăn
# replaced đốc with 4Giám
# replaced chim with hót
# "Key 'đến.' not present in vocabulary"
# ['Ăn trộm 3 con chim của giám đốc sở bị đi tù 7 năm, còn thảm sát cả 1 thế hệ thì không ai sờ đến.', '2']
# replaced gần with Gần
# replaced thằng with đứa
# replaced mẹ with bà
# replaced theo with kiểu
# replaced cách with cách
# replaced của with cảu
# replaced sale with Ssale
# replaced cc with Yeabd66
# replaced sale with gìsale
# "Key '😆😆' not present in vocabulary"
# ['sale cc à thầy 😆😆', '2']
# replaced ta with cô
# replaced cái with thì
# replaced Nhạc with 1Nhạc
# replaced ba with Cả
# replaced đi with để
# replaced với with cùng
# "Key ':))' not present in vocabulary"
# ['Cô My ơi ở lại với e đi :)) kệ mẹ thg lozzzz ba gà :))))', '2']
# replaced CÁCH with 10CÁCH
# "Key '?!' not present in vocabulary"
# ['TÂM THẦN ?!? CHỨ KG PHẢI TRỊNH THƯỢNG ?! CÁCH HÀNH XỬ CỦA 1 NHÓM CÓ TIỀN CÓ QUYỀN NÊN BỐ LÁO !!!', '2']
# replaced này with mới
# replaced thế with chứ
# "Key 'tiktok.' not present in vocabulary"
# ['Đến đây từ tiktok. Xem xem người này như thế nào. Ra là như thế này. Co thế này mà đi đến đâu vệ sỹ và fan bủa vây tới đó.éo hỉu', '2']
# replaced sạo with Ậy
# replaced sạo with đẻng
# replaced Đám with đám
# replaced Minh with Quang
# replaced Minh with Hằng4
# replaced chậm with chậmrãi
# "Key 'cdmm' not present in vocabulary"
# ['Anh Minh chậm cdmm', '2']
# replaced mẹ with bố
# replaced Tuan with ArTuan
# replaced Nguyen with Nguyet
# "Key '@Anh' not present in vocabulary"
# ['@Anh Nguyen Tuan  biến con mẹ mày', '2']
# replaced ưa with dễ
# replaced ưa with trịLí
# replaced bà with cụ
# replaced hộ with báncăn
# replaced cho with các
# replaced Độ with ▄▀▄Cá
# replaced tịch with WiR1Chủ
# replaced máy with loạimáy
# replaced phố with ngõ
# replaced , with Dù
# replaced hại with lợi
# replaced Lũ with khũ
# replaced nổi with nổi
# replaced gì with nó
# replaced Minn with Minnows
# "Key 'cailon' not present in vocabulary"
# ['Phương Minn k nghe nổi thì out mắc cailon gì dislike🙂', '2']
# replaced tuc with SIEUTHIVPBáo
# replaced la with eya
# replaced tap with 202603.0
# replaced khai with giảngLầm
# replaced đều with thường
# replaced riêng with riêngcủa
# replaced để with Để
# replaced văn with khíLuận
# replaced đền with đền
# replaced của with riêng
# replaced HL with -9480
# replaced báo with PetroTimes
# replaced bậy with Chửi
# replaced vào with khi
# replaced hối with Xám–
# replaced đấy with rồi
# replaced cụ with haySo
# replaced tôn with Tôn
# replaced kiều with Cosuvina
# replaced càng with sẽcàng
# "Key 'kiều.' not present in vocabulary"
# ['Trăm năm kiều vẫn là kiều. Đu càng qua mỹ xao lol vẫn hay', '2']
# replaced bò with bòDa
# replaced con with cha
# replaced Quang with Hưng
# replaced lúc with giờ
# "Key '🤣🤣' not present in vocabulary"
# ['a lúc nào chả xạo lon 🤣🤣', '2']
# replaced abe with acy
# replaced thì with nên
# replaced thì with nên
# "Key '@Vh' not present in vocabulary"
# ['@Vh Fg vo van hoa vo hoc', '2']
# replaced được with cũng
# replaced làm with được
# replaced em with anh.em
# replaced thi with gaokao
# replaced Vinh with VinhVinh
# replaced hat with bai`
# replaced TAM with TUẾ
# replaced hat with Bedarf
# replaced cam with quýt
# replaced của with của
# replaced đã with mà
# replaced kê with %Thống
# replaced đã with sẽ
# replaced thằng with 1thằng
# replaced nôi with Nôi
# replaced nhanh with tốt
# replaced hơn with với
# replaced não with Werfen
# replaced ngu with xuẫn
# replaced ngày with Ngày
# replaced thường with dùng
# replaced phải with buộc
# replaced to with be
# replaced ak with ah`
# replaced có with Có
# replaced an with toàn4
# replaced chợ with sạp
# replaced CON with CỌP
# "Key 'TẬT.' not present in vocabulary"
# ['GỌI TRẦN DẦN LÀ CON TINH TRÙNG KHUYẾT TẬT.', '2']
# replaced ĐÚNG with KHÔNG
# replaced NÀO with VẬY
# replaced ĐẸP with TỐT
# replaced thầy with côThầy
# "Key '<3' not present in vocabulary"
# ['Thầy lồn được cái sủa dơ, yêu thầy <3', '2']
# replaced báo with Báo
# replaced ntn with pải
# replaced lũ with lủ
# replaced này with thì
# "Key '=)))' not present in vocabulary"
# ['Thằng Ad này muốn ăn chửi đây mà =))) ~', '2']
# replaced duoi with ß€Ñguy€n
# replaced no with Inbō
# replaced tong with Alebtong
# replaced đối with t­ượng
# replaced hữu with ngạng
# replaced nầy with cuả
# replaced mà with sẽ
# replaced gì with mà
# replaced ấy with mà
# replaced đã with có
# replaced hiệu with quảĐầu
# replaced thương with thươngnơi
# replaced công with nghệKiên
# replaced dân with củangƣời
# replaced người with ngừơi
# "Key '!!!...' not present in vocabulary"
# ['học dối - học giả...kiến thức nông cạn, phát biểu nông nỗi!...Japan Technology thương hiệu toàn cầu mà đi chê bai !!!... làm ảnh hưởng đến quan hệ hữu nghị hợp tác với đối tác Nhật Bản...Ai làm được việc- người ấy có lý!!!...đằng nầy công nghệ xử lý nước thối made in Hà nội của nhóm lợi ích chưa làm được gì trong khi $ tiền thuế của dân đã đổ hàng bao nhiêu tỷ bạc vào mà nước thối vẫn thối!!!...', '2']
# replaced mày with Tao
# replaced đó with là
# replaced chó with becgie
# "Key '@Tiktok' not present in vocabulary"
# ['@Tiktok Official hùa theo là chó vậy mày cũng hùa đó', '2']
# "Key 'nói,' not present in vocabulary"
# ['Đào Q.Anh Q.Anh Đào câu kia là ông Độ nói, người lớn th cha m', '2']
# replaced muôn with ngàn
# replaced muôn with ngàn
# replaced đời with Đời
# "Key 'thế,' not present in vocabulary"
# ['Cộng sản là thế, muôn đời', '2']
# replaced khùng with nùng
# replaced thêm with càng
# replaced khùng with ùng
# replaced tên with Tên
# replaced cách with biết
# replaced mang with giúp
# replaced mà with vì
# replaced mà with vì
# replaced biết with không
# replaced không with nhưng
# replaced chùi with Chùi
# replaced ơi with ôi
# replaced chùi with rửa
# replaced mất with làm
# "Key '😂' not present in vocabulary"
# ['Cô ơi cô có dòng họ vs Hồ Xuân Hương không cô:)) cô nói gì 1 tỉ không bằng vải chùi âm đạo của cô hả 😂 vậy trước tiên thì cô thay lại cái áo của mình đi nghe cô😂 dù sang cở nào thì cái áo là nó làm mất hình tượng hết đó cô ơi 😂...', '2']
# replaced giun with đỉa
# "Key 'hơ...' not present in vocabulary"
# ['DM...assmin...mặt thộn...sao mài thích bới cứt tìm giun thế thằng mặt thộn...hơ hơ hơ...', '2']
# replaced ung with thưNếu
# replaced của with cảu
# replaced nặng with nặng360
# replaced khùng with khùngBốn
# replaced rồi with rùi
# replaced Ba with ĐìnhĐổ
# replaced gửi with gửi
# replaced càng with rất
# replaced cái with hai
# replaced TÔN with THỜ
# replaced TÔN with HUỆ
# replaced LÒ with LÒ
# replaced môi with Mím
# replaced sửa with chữaĐổi
# replaced dùng with Dùng
# "Key 'tả.' not present in vocabulary"
# ['Cái môi của bad này ko biết dùng từ nào để tả. Chỉnh sửa nhìn ghê vl', '2']
# replaced Rọi with ðêm
# replaced Ba with mưoi
# replaced Béo with mạp
# replaced Xin with hãy
# replaced Đỗ with Võ
# replaced thiếu with không
# "Key 'ạ.' not present in vocabulary"
# ['Xin lỗi nhưng mà bạn nói chuyện thiếu i ốt vcl ra bạn Đỗ Huy ạ.', '2']
# replaced ngay with trong
# replaced câu with hỏi
# replaced sinh with sanh
# "Key '///' not present in vocabulary"
# ['Thí sinh xứ mình ngay khi nghe câu hỏi sẽ trừng mắt chửi MC: Phản động, phản động. Rồi nhìn cả lượt BGK: Đồ ///', '2']
# replaced nó with sẽ
# replaced đỉ with ẽm
# replaced Con with Chú
# replaced Thái with Singapore–Thái
# replaced not with bhikkhu
# replaced ba with bảy
# replaced của with này
# replaced liệu with rằng
# replaced này with đây
# replaced mồm with pesbovis
# replaced lời with nói
# replaced Lại with HT700
# replaced dell with dellmáy
# replaced l with îng
# replaced xạo with Bậy
# replaced Nghe with Nói
# replaced ko with cugnx
# "Key 'Bắc.' not present in vocabulary"
# ['Nghe đâu thằng ad là dân Bắc. Nó mún ngửi đít miền Nam mà ko được nên tức ấy mà', '2']
# replaced hơn with gần
# replaced hơn with hẳn
# replaced nhiều with rất
# replaced vậy with biết
# replaced để with và
# replaced một with loạt
# replaced Che with che
# replaced thần with 【Thần
# replaced cái with thì
# replaced đi with sẽ
# replaced thứ with này
# replaced dâu with chồngCon
# replaced hết with lại
# replaced thơm with ngậy
# replaced vốn with vốn
# replaced đó with nó
# replaced dâu with chồngCô
# "Key 'người!' not present in vocabulary"
# ['Trần ĐOÀN chuyên bán mấy cái hàng fake mà nói xạo nói láo, vốn có 40k,50k một chai đi bán 200k,300k. Chưa hết nó còn dám nói hàng chính hãng vài triệu sale còn 200k, thứ lừa đảo, mất dạy. Ai mà mua hàng con này sài coi chừng ung thư da đó nha, nó bỏ ba cái chất gây nghiện vô để ngta mua hoài đó, sài vô đi rồi có ngày ung thư hỏi sao xui, thà mua chai dâu thơm chính hãng sài hơi đắt mà thơm lâu, an toàn nha mọi người!', '2']
# replaced là with Vì
# replaced chả with Chẳng
# replaced có with là
# replaced cmt with Fynnz
# replaced lại with thì
# replaced 2 with 3
# "Key 'quá,' not present in vocabulary"
# ['từ từ đừng cmt nhanh quá, từ từ nghệ sĩ nỗi noi vào 1 2 câu rồi cái tụi mầy lại dơ cái tánh chó ra tung hô à, lũ đa nhan cách :))))))', '2']
# replaced diễn with diễnSau
# replaced phá with tangKhám
# replaced diễn with biễu
# replaced có with đủ
# replaced điều with này
# replaced biết with rằng
# replaced kì with kỳ
# replaced ? with ư
# replaced bí with ẩnXe
# replaced qua with trải
# replaced thứ with nhì
# replaced xem with được
# replaced khựa with Tầu
# replaced Ủng with Jogger
# replaced tổ with chưc
# replaced là with sẽ
# replaced dân with Dân
# replaced Lủ with Cót
# replaced Trần with Tống
# replaced vẫn with tuy
# replaced dịch with vụtại
# replaced sư with –gia
# replaced Tuấn with Huy
# replaced Tuấn with Cường
# replaced Anh with Tiếng
# replaced này with được
# replaced đã with hề
# replaced chúa with chúa》
# "Key 'CHÓ,,CSVN' not present in vocabulary"
# ['TRẦM NGÂM CỨT,,tên nào đi ngược lợi ích nhân dân đều là bò ngu tung HỨNG HÒ BẢ CHÓ,,CSVN là chúa lừa dân và ăn cướp đồng bào ,,loại bỏ cs là nhiệm vụ chính của nhà báo ngu dốt và chính nhân dân', '2']
# replaced ôn with htttĐổi
# replaced Bé with ba13
# replaced tao with thằng
# replaced đấy with chứ
# replaced Ở with Về
# "Key 'mát😡😡' not present in vocabulary"
# ['Ở đấy ngột ngạt quá thì đưa nó qua vũ hán cho nó thoáng mát😡😡', '2']
# replaced võ with Võ
# replaced từ with 15
# "Key 'AHBP,' not present in vocabulary"
# ['Ai làm đc gì ngoài dùng võ mồm ca thán, thơ vịnh vè trào phúng, chửi đổng, AHBP, và xuất phát từ cái tâm vì nước vì dân thực sự? Ai làm gì đó đi chứ, đừng thủ dâm kiểu này mệt lắm :(( Với lại gần tết, ai cũng cố gắng tìm lương tháng 13 mà .. gắng cày thêm job cho tốt. Bên kia mới thưởng tốt', '2']
# replaced thể with thao51
# replaced tưởng with rằng
# replaced bất with ngờĐưa
# replaced Mao with Trạch
# replaced thằng with đứa
# replaced Ấy with mà
# replaced con with conCon
# replaced Chó with bécgiê
# replaced linh with tinhEye
# replaced coi with như
# "Key 'ko.' not present in vocabulary"
# ['Người ko ra người.ngợm ko ra ngợm.ý thức thì như đống rác.nhà nước nên bỏ tù những thằng coi thường pháp luật và tính mạng người khác như nó.phạt thật nặng xem nó có im mỏm nó ko.', '2']
# replaced nữa with chứ
# replaced này with này
# replaced còn with chưa
# replaced thì with rồi
# replaced viện with viện
# replaced cấp with 28Cung
# replaced khai with Khai
# replaced nhân with đại
# replaced Nam with Tây
# replaced đã with vì
# replaced dẹp with HCMfoot
# replaced của with cuả
# "Key '😉' not present in vocabulary"
# ['Giờ ko đánh cũng đã khai chính cờ đỏ sao vàng là bọn khủng bố.cần phải dẹp ngay bọn khủng bố cờ đỏ sao vàng này ra khỏi xã hội Việt Nam và cả nhân loại của thế giới 😉', '2']
# replaced năng with lượng14Năng
# replaced chống with Quốcchống
# replaced khi with việc
# replaced trả with Đổi
# replaced người with ngưới
# replaced hết with rồi
# replaced 3K with 60FPS
# replaced 3K with MOB
# replaced xạo with Bậy
# replaced tàu with boong
# replaced ra with tỏ
# replaced tỷ with m2
# replaced cúng with dường
# "Key 'bây,' not present in vocabulary"
# ['Đéo mẹ, MC Phan Anh có nhận lương từ dân tụi tao ko, hết lòng vì người vùng lũ, còn tụi mày có đứng ra kêu gọi và hết lòng lo cho dân ko hay chỉ là kêu gọi xong đem cúng mồ mã ông bà nhà tụi bây, đm cứ tưởng dân giờ ngu lắm ấy.', '2']
# replaced của with cảu
# replaced ánh with liếc
# replaced cuộc with cuộc
# replaced lại with cho
# replaced con with conCòn
# replaced quay with dừng
# replaced vl with dzất
# replaced này with của
# replaced vl with vcc
# replaced Trần with T.Linh
# replaced Trần with Đặng
# replaced nhà with xây
# replaced Bây with giờ=
# replaced Khẩu with khẩu
# replaced giơ with tay
# replaced Địt with Lồn
# replaced Cười with Cười
# "Key 'rồi.' not present in vocabulary"
# ['Địt mẹ các bạn ý. Cười rụng con mẹ nó mồm rồi.', '2']
# replaced đóng with Máyđóng
# replaced bị with đã
# replaced add with remove
# replaced chỉ with không
# replaced ngu with đần
# replaced tràn with dầutràn
# replaced mừng with ♥Chào
# replaced máu with f˜s
# "Key 'hỉ!!!!!' not present in vocabulary"
# ['Vài trăm xúât quà mừng như vậy là gìau hơn cả Trump oz! Tội nghịêp bọn tư bản bóc lột hút máu người lao động cả đời dell bằng quà mừng của mấy cán bộ do dân và vì dân hỉ!!!!!', '2']
# replaced mấy with cái
# replaced Ghép with PhotoScapeGhép
# replaced cl with yk
# replaced buộc with muốn
# replaced phải with cần
# replaced buộc with muốn
# replaced đánh with đánh
# replaced trước with đầu
# replaced khi with việc
# "Key 'ThanhHuy' not present in vocabulary"
# ['ThanhHuy Nguyen dơ vcl=)))', '2']
# ...
# replaced chuyện with chuyệnđó
# "Key 'học,' not present in vocabulary"
# ['Thắng Ok m chui từ cái lol cho ra nói chuyện như thằng vô học, đmm ai nc vs m nhàu vô đây cắn bậy', '2']
# replaced ai with mà
# replaced chó with samoyed
# replaced rước with Rước
# replaced từ with cả
# replaced giặc with Phẻ
# replaced qua with trong
# "Key 'nhất.' not present in vocabulary"
# ['Bọn xu nịnh là những kẻ làm hư cán bộ, và là những kẻ yếu kém chuyên môn nhất.', '2']
# "Key 'dân.' not present in vocabulary"
# ['Ở Vietnnam tụi nó ăn tiền bồi thường ô nhiễm của người dân. Ở Việt Nam! Tụi nó ăn tiền để làm ngơ formosa gây ô nhiễm.', '2']
# replaced biến with biếnthành
# replaced đi with Đi
# replaced nghĩa with nghĩa—
# "Key 'áp!' not present in vocabulary"
# ['Thương anh í quá, sao chính quyền không cho ông cách ly ở nhà tang lễ cho tiện nhang đèn, hòm gỗ kèm nến lung linh cho ấm áp!', '2']
# replaced xứng with xứngEng
# replaced người with Người
# replaced nam with trungáo
# replaced thầy with thầy
# replaced đâu with vậy
# replaced đá with dá
# replaced Thanh with NgânMP3
# replaced ấy with họ
# replaced bạn with muốn
# replaced mặc with pyjamas
# replaced ai with Ai
# replaced tao with thằng
# "Key 'con?' not present in vocabulary"
# ['Trần Hoàng Long đĩ mẹ m con? Trần Hensy của c nè', '2']
# 'Key \'Đảng""\' not present in vocabulary'
# ['"Từ đầu tới cuối các trang ""Yêu Đảng"" Đều đổ cho thủy triều đỏ cả và xỉ vã thậm tệ những người nói do formosa gây ra !Đến khi sự việc vỡ lỡ vẫn ko 1 lời xin lỗi !"', '2']
# replaced giog with gia`
# replaced cai with Naltrexone
# "Key 'phuoc,' not present in vocabulary"
# ['Troi oi,con duc rua nay no lam phuoc, ma cai mom no giog cai ham cau lau nam .doi k', '2']
# replaced tịch with NgaChủ
# replaced làm with Làm
# replaced nhỉ with Chắc
# replaced nhìu with thix
# replaced luận with Luận
# "Key 'nọ,' not present in vocabulary"
# ['Vào trường lớp giáo viên dạy ta bải vệ môi trường cây cối này nọ, song thực tế các bác lớn hằng ngày vẫn đưa ra nhìu dự án, đề xuất để rồi rừng ít lại còn ít hơn. Và lại đưa đề nghị luận xh về việc chặt phá rừng', '2']
# replaced bổng with xổng
# replaced cửa with phía
# replaced cửa with mở
# replaced Người with rắnNgười
# replaced là with thì
# replaced Nó with Hắn
# "Key 'niếp' not present in vocabulary"
# ['1 con phố đang xinh đẹp, nề niếp bổng thằng chó ad nó ỉa trước cửa nhà nó. Người ta ko cho, nó bảo ỉa như thế để tạo mùi thơm cho khu phố. Nó thích sự khác bjệt là thế', '2']
# replaced mất with dần
# replaced hộ with ủg
# replaced nghe with ngheMột
# replaced làm with cũng
# replaced đây with sau
# replaced đâu with vậy
# replaced nói with Nói
# replaced nên with thì
# "Key '=))' not present in vocabulary"
# ['quan trọng là cãi tụi nó nên tụi nó cho lên đĩa, chứ làm sai thì ai nào ko sai? với lại biết ai chơi ko mà nói ông thanh nào đì, dám nói ông thanh đà nẵng lắm ah` =))', '2']
# replaced T.Q with VnE
# replaced toan with toaǹ
# replaced nguoi with 2nguoi
# "Key 'lozzzz' not present in vocabulary"
# ['Cô My ơi ở lại với e đi :)) kệ mẹ thg lozzzz ba gà :))))', '2']
# replaced mẹ with Mẹ
# replaced chết with chết=
# replaced con with conCòn
# replaced tiền with tiềnĐi
# replaced tiền with trả
# replaced dã with manKhi
# replaced đồ with dồ
# replaced là with Là
# replaced dân with người
# replaced những with nhiều
# replaced cộng with đồng—
# replaced có with đủ
# replaced cộng with cộng
# replaced theo with kiểu
# replaced nghĩ with nếu
# replaced vc with nvay
# replaced nằm with cạnh
# replaced để with mà
# replaced dân with toàn
# replaced Xong with Sau
# replaced bẫy with Bẫy
# "Key 'nó.' not present in vocabulary"
# ['Đ m có cái loại doanh nghiệp làm ăn bố láo cho cả ruồi vào nước uống quảng cáo rầm rộ có lợi cho sức khỏe -_- khỏe cái mả cha nhà chúng nó. Xong lúc người ta dàn xếp đôi bên theo kiểu dân sự thì úp sọt đánh bẫy người ta. CÒn bọn chức trách có thẩm quy', '2']
# replaced nghe with ngheTai
# replaced công with nghệVì
# replaced thấy with thì
# replaced thi with thiĐề
# replaced dr with Kořalník
# replaced nhìu with nhiều
# replaced thức with nang»Kiến
# replaced chưa with chẳng
# replaced chứ with Chắc
# replaced vớ with quơ
# replaced nhấp with nhấpchuột
# replaced việt with nammô
# replaced và with là
# replaced ta with nó
# replaced của with chính
# replaced Thánh with Gioa
# replaced do with là
# replaced Văn with Hoá
# replaced xuống with xuốn
# replaced đặc with biệt4
# replaced nó with đó
# replaced kêu with vang
# replaced điện with điệnđiện
# replaced đừng with chớ
# replaced Thăng with Long
# replaced va with scơ
# replaced đit with sexx
# replaced vào with tới
# replaced bạn with Nếu
# replaced phải with cũng
# replaced dã with dả
# replaced dây with đeo
# replaced lên with trở
# "Key 'miệng,mà' not present in vocabulary"
# ['chửi nhau sao kg gọi Phone chửi cho dã cái miệng,mà lên dây khoe vàng hả cha,ỉa déo ra cũng dưa lên,bó tay,', '2']
# replaced ? with gì
# replaced hộ with Hộ
# replaced hộ with báncăn
# "Key 'Dlv' not present in vocabulary"
# ['Dlv sủa hộ ?', '2']
# replaced thầy with Thầy
# replaced lồn with Lồn
# replaced thầy with thày
# replaced nhu with cÇu
# replaced lợn with vịt
# replaced lợn with chó
# replaced Tiệp with Tiệp
# replaced tại with khắp
# "Key 'Hmm,' not present in vocabulary"
# ['Hmm, Trời đã sinh ra Tuấn tại sao còn sinh ra Tiệp :( haizzz', '2']
# replaced thôi with nữa
# replaced ông with bà
# "Key '🙂' not present in vocabulary"
# ['Thôi thôi ông im cmn đê ... 🙂', '2']
# replaced sao with chăng
# replaced ba with sáu
# replaced sao with Sao
# replaced thế with chứ
# replaced do with và
# replaced đạp with xe23
# "Key 'bố.' not present in vocabulary"
# ['Không cho chúng bố ăn là chết với chúng bố. Thiên đường xhcn nó thế đấy con ạ.', '2']
# replaced thu with phóng
# replaced ba with hai
# replaced ba with mười
# replaced bệnh with bịnh
# replaced bệnh with chữa
# replaced này with mới
# replaced đạt with cao
# replaced nhất with nhất
# replaced đạt with 102,25
# "Key 'là...thần' not present in vocabulary"
# ['Trần Dần đã đạt cảnh giới cao nhất của thần quyền là...thần kinh', '2']
# "Key 'là???cả' not present in vocabulary"
# ['Ngụ ý của anh bảy vịt quay là???cả đất nước Việt Nam chỗ nào cũng có bọn tàu cộng nó nắm đầu hết.', '2']
# replaced Ai with Là
# replaced xin with muốn
# replaced no with Inbō
# replaced k with Nhg
# replaced mấy with bốn
# replaced Tien with NhocTien
# list index out of range
# ['"Chào em ! Hôm nay em đẹp lắm luôn . Bọn chị ủng hộ em ! Em hãy dùng văn hóa chửi - Chửi đau chửi đớn con chó Linh em nhé .']
# replaced em with ko
# 'Key \'."\' not present in vocabulary'
# ['Chào em ."', '2']
# replaced CHỊ with THÚY
# replaced háng with đũng
# replaced nọc with hèo
# "Key 'Moá,' not present in vocabulary"
# ['Moá, quái thai', '2']
# replaced bà with cụ
# replaced quá with quá
# replaced cụ with gìa
# replaced Ôi with Úi
# replaced ở with Ở
# replaced tức with tửi
# replaced phải with được
# replaced cần with chỉ
# replaced lồn with Gelgeç
# replaced ta with Ta
# replaced nuoc with inox..sua
# replaced dat with 2017XSVT
# replaced của with cảu
# replaced đáo with 1Độc
# replaced này with này
# replaced buồi with địt
# replaced Đức with Berlin
# replaced Trần with Trỗi–Trần
# replaced khoc with hjeu
# replaced tu with Bep
# replaced len with ghile
# replaced cái with kia
# replaced mặt with sắc
# replaced còn with vẫn
# replaced mới with này
# replaced lắm with nhỉ
# replaced nhân with Nhân
# replaced triệu with triệu=
# replaced con with conCòn
# replaced mỹ with mĩ
# replaced còn with chỉ
# replaced con with đứa
# replaced giờ with trưa
# replaced này with đây
# replaced kiểu with kiểu
# replaced ấy with Cô
# replaced cc with ccm
# replaced cc with cs113
# replaced Vinh with VinhVinh
# "Key 'like.' not present in vocabulary"
# ['Đíu ai like. Cho thầy đi ăn cắp luôn', '2']
# replaced gánh with gáng
# replaced kệ with kệ
# "Key '=))' not present in vocabulary"
# ['Bố đéo gánh =)) kệ con mẹ chúng m =))', '2']
# replaced mà with vì
# replaced nhậm with chức
# "Key 'Vâng!' not present in vocabulary"
# ['Vâng! Báo từ tháng 12 năm ngoái mà lại chê trình độ của người nhậm chức năm nay, Vãi bướm quá', '2']
# replaced lon with Lon
# replaced lon with hộpDây
# replaced Giàu with GiàuVTV9
# replaced mà with là
# replaced 10 with 11
# replaced hàng with Hàng
# replaced gì with là
# replaced Quốc with Quốchội
# replaced thì with Vậy
# replaced họ with Họ
# replaced ảnh with ảnhChụp
# replaced thì with phải
# 'Key \'cứt\\""\' not present in vocabulary'
# ['"Tâm Nguyễn Phát ngôn đúng chất \\""não cứt\\"" . Người Việt mà đéo về Việt thì ông muốn họ sang Trung Quốc à ? Giàu thì cũng tiền họ làm ra , có xin nhà ông đéo đâu ? Họ về đéo ảnh hưởng đến đất nước là được . Ý kiến cái đéo gì ."', '2']
# replaced lũ with ct12a
# "Key '@Hung' not present in vocabulary"
# ['@Hung Nguyen nhân dân VN tức là cờ đỏ. Còn đám cờ vàng là lũ súc vật lưu vong. Hiểu hông?', '2']
# replaced cứt with lợn
# replaced mẹ with Mẹ
# replaced xin with muốn
# replaced người with làngười
# replaced hết with lại
# replaced mìh with mjk
# "Key ':v' not present in vocabulary"
# ['Nhà có mấy kg cá mắm để lâu nên chắc cũng đủ khắm với trình của thắm...chính thức cần chịch đứa ad này và tặng nó lô cá mang chửi thuê cho xứng với nghề :v', '2']
# replaced vo with gạoBí
# replaced no with Inbō
# replaced no with Aiyoku
# replaced mấy with mấy
# replaced Chắc with Hẳn
# replaced thuốc with thuốc–
# "Key 'đó.ah' not present in vocabulary"
# ['Có ba giàu nhỉ.vay sao có ba con lừa bịp cua cô hieu mấy trăm triệu vậy? à nè cô bà ơi.net đẹp của cô k dụng hàng ai luôn đó.ah phải gọi là giống công công hơn.haha. Chắc bà này bà quên uống thuốc rồi cả nhà ơi.khung hết thuốc chữa đồ thần kinh', '2']
# replaced thôi with Chứ
# replaced thôi with lắm
# replaced đĩ with Hĩm
# replaced mới with rồi
# replaced từ with cả
# replaced chất with lượngchất
# replaced bảo with mậtTra
# replaced mua with bán
# replaced ( with 2
# replaced nhăn with Colagel
# replaced não with thểu
# replaced ổng with tui
# replaced ban with Ủy
# replaced chăm with nuôi
# replaced cho with đem
# "Key 'Phuk' not present in vocabulary"
# ['Phuk cho mụ Tiến về làm trưởng ban chăm sóc sức khỏe cho cán bộ. Ahihi', '2']
# replaced bẩn with thĩu
# replaced sống with sốngSống
# replaced sống with sốngvà
# replaced Hoàng with hoàng
# replaced phúc with emHạnh
# replaced fuck with fuck18
# replaced Cún with Suti
# replaced k with tnay
# replaced chữ with tiếngFont
# replaced cai with lào
# replaced si with Si
# replaced nguoi with nguoi`
# replaced để with và
# replaced Rất with Không
# replaced vụ with ĐX
# replaced hó with ẩ
# replaced con with đứa
# replaced sờ with 大平興寶
# replaced rẻ with MỹĐặt
# replaced quốc with quốcThủ
# replaced Bán with i%%%%
# replaced đéc with rép
# replaced sa with varṇa
# replaced sa with 如是我聞
# replaced thằng with thằngthằng
# replaced nghề with nghềTìm
# replaced ad with nauseam
# "Key 'mẹ,thiếu' not present in vocabulary"
# ['Nghèo chết mẹ,thiếu nợ người ta chết mẹ.Bộ mặt con mẹ gì.NGUỴ BIỆN.', '2']
# replaced hay with cũng
# replaced tàu with xuồng
# replaced này with được
# replaced thối with thốiBắt
# replaced Thắm with Đượm
# replaced Thắm with Hường
# replaced Đúng with Thế
# replaced mời with Mời
# "Key 'chức!!!' not present in vocabulary"
# ['Điên!!! Ông này điên điên mà lai được cccđ mời khi có sự kiện. Đúng là một lũ điên có tổ chức!!!', '2']
# replaced thúi with ♥Nhiᴖ
# replaced hoắc with thoắc
# "Key '🤭' not present in vocabulary"
# ['Hải Yến xinh gái mà cmt thúi hoắc à 🤭', '2']
# "Key 'lắm...Đm' not present in vocabulary"
# ['Địt mẹ m óc cức lắm...Đm cho cũng chửi Đéo cho cũng chửi...Đm.tay nhanh hơn não à...Đéo đc bố mẹ cho đi học à...thua con chó', '2']
# "Key 'hành,' not present in vocabulary"
# ['Viết cái cho lòng nhẹ ,đúng lúc máy bay rơi là lúc t bị chính quyền xã củ hành, thế nên a ức chế kệ mẹ bố con thằng nào chết ,người trong xã còn hành nhau thì tw nó cũng hành cút', '2']
# replaced Ở with Mà
# replaced giúp with nhằm
# replaced Rảnh with quỡn
# "Key 'cha.' not present in vocabulary"
# ['Rảnh thì giúp mẹ giúp cha. Ở đây sống chậm mả cha chúng mày...', '2']
# replaced chết with chết
# replaced mấy with một
# replaced chữa with bệnhXoa
# replaced t with wasn
# "Key 'thôi,' not present in vocabulary"
# ['Le Viet Anh nếu nhà t có ng bị thì sẽ xung phong đi cách ly chứ ko để lâu ngày đâu mà bị lm sao cả, chỉ có mấy loại cm trốn cách ly ko chữa kịp mới chết thôi, loại như cm thì nên chết sớm ko lại lây ra cộng đồng', '2']
# replaced chán with amchán
# replaced cụ with Arnơ
# replaced địt with soclo
# "Key ':D??' not present in vocabulary"
# ['Anh vừa nói cc gì vậy Abe :D??', '2']
# replaced thiết with đểthiết
# replaced ở with ,
# replaced tắng with tăn
# replaced bọn with bọn
# replaced còn with thì
# replaced xả with 捨
# replaced đéo with đếch
# replaced Yến with Vân
# replaced m with mx
# replaced qua with trên
# replaced nay with trước
# replaced gia with đìnhÝ
# 'Key \'""đất\' not present in vocabulary'
# ['"Hóng bò đỏ vào sủa ""đất nước mình còn nghèo"""', '2']
# replaced có with đã
# replaced nghiệt with kiếp
# replaced Nhìn with raNhìn
# replaced đứng with đứng
# "Key ':(' not present in vocabulary"
# ['Thằng già kia đứng cười chứ :(', '2']
# "Key 'chó@@' not present in vocabulary"
# ['Dương Thái Phước ba gà not ba chó@@', '2']
# replaced ngày with tuần
# "Key 'xác.' not present in vocabulary"
# ['Có ngày sẽ có tin con này phơi xác.', '2']
# replaced chó with vịt
# replaced má with máRau
# replaced chó with chóe
# "Key 'đó,' not present in vocabulary"
# ['Đm, đéo hiểu sao cái đầu của nó lại nói ra đc những lời đó, so sánh nó với con chó thì nhục con chó qá', '2']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-4fdbb9e86ac8> in <cell line: 317>()
#     317 if __name__ == "__main__":
#     318     # generate augmented sentences and output into a new file
# --> 319     gen_eda(args.input, args.output, alpha=alpha, num_aug=num_aug)
#
# <ipython-input-5-4fdbb9e86ac8> in gen_eda(train_orig, output_file, alpha, num_aug)
#     294                 label = parts[1]
#     295                 sentence = parts[0]
# --> 296                 aug_sentences = eda(sentence, alpha_sr=alpha, alpha_ri=alpha, alpha_rs=alpha, p_rd=alpha, num_aug=num_aug)
#     297                 for aug_sentence in aug_sentences:
#     298                     # writer.write(label + "\t" + aug_sentence + '\n')
#
# <ipython-input-5-4fdbb9e86ac8> in eda(sentence, alpha_sr, alpha_ri, alpha_rs, p_rd, num_aug)
#     224     # sr
#     225     for _ in range(num_new_per_technique):
# --> 226         a_words = synonym_replacement(words, n_sr)
#     227         augmented_sentences.append(' '.join(a_words))
#     228
#
# <ipython-input-5-4fdbb9e86ac8> in synonym_replacement(words, n)
#      73     num_replaced = 0
#      74     for random_word in random_word_list:
# ---> 75         synonyms = get_synonyms(random_word)
#      76         if len(synonyms) >= 1:
#      77             synonym = random.choice(list(synonyms))
#
# <ipython-input-5-4fdbb9e86ac8> in get_synonyms(word)
#     116 def get_synonyms(word):
#     117     synonyms = []
# --> 118     sn = model.most_similar(word)
#     119
#     120     for k in sn:
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     850         if not topn:
#     851             return dists
# --> 852         best = matutils.argsort(dists, topn=topn + len(all_keys), reverse=True)
#     853         # ignore (don't return) keys from the input
#     854         result = [
#
# /usr/local/lib/python3.10/dist-packages/gensim/matutils.py in argsort(x, topn, reverse)
#      75         return np.argsort(x)[:topn]
#      76     # np >= 1.8 has a fast partial argsort, use that!
# ---> 77     most_extreme = np.argpartition(x, topn)[:topn]
#      78     return most_extreme.take(np.argsort(x.take(most_extreme)))  # resort topn into order
#      79
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in argpartition(a, kth, axis, kind, order)
#     856
#     857     """
# --> 858     return _wrapfunc(a, 'argpartition', kth, axis=axis, kind=kind, order=order)
#     859
#     860
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      57
#      58     try:
# ---> 59         return bound(*args, **kwds)
#      60     except TypeError:
#      61         # A TypeError occurs if the object does have such a method in its
#
# KeyboardInterrupt:

# %% [markdown]
# # Results and concat with original

# %%
 # !pip install pandas==1.4
# Out:
# Collecting pandas==1.4
#   Downloading pandas-1.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.4) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas==1.4) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas==1.4) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.6.0 requires pandas>=1.5.0, but you have pandas 1.4.0 which is incompatible.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 1.4.0 which is incompatible.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 1.4.0 which is incompatible.
# plotnine 0.12.4 requires pandas>=1.5.0, but you have pandas 1.4.0 which is incompatible.
# Successfully installed pandas-1.4.0

# %%
# TRAIN
# concat train original with original

import pandas as pd

DATA = '/content/train.csv'
DATA_AUG = '/content/augmented_d3232ataset(6).txt'

DATA_AUG_FINAL = '/content/train_augme3232nted_dataset(1).csv'

data = pd.read_csv(DATA, index_col=False)
data_hate = pd.read_csv(DATA_AUG, index_col=False,error_bad_lines=False)
#, error_bad_lines=False
#data_hate = data_hate.iloc[: , 1:]
data_hate.drop_duplicates(subset ="free_text", keep = False, inplace = True)

data_aug = pd.concat([data, data_hate])

data_aug.to_csv(DATA_AUG_FINAL, index=False)

# %%
# Extra augmentation
import pandas as pd

DATA = '/content/train.csv'

DATA_AUG = '/content/drive/MyDrive/new_dataset15.5/augmented_dataset_label_1_num8_0.05_wordnet.txt'
DATA_AUG_2 = '/content/drive/MyDrive/new_dataset15.5/augmented_dataset_label_2_num8_0.15_wordnet.txt'

DATA_AUG_FINAL = '/content/train_augmented_dataset_label12_num8_0.15_wordnet.csv'

data_hate = pd.read_csv(DATA_AUG, index_col=False, error_bad_lines=False)
#, error_bad_lines=False
data_hate_2 = pd.read_csv(DATA_AUG_2, index_col=False, error_bad_lines=False)
data_hate_final = pd.concat([data_hate, data_hate_2])
data_hate_final.drop_duplicates(subset ="free_text", keep = False, inplace = True)

data = pd.read_csv(DATA, index_col=False)
data_aug = pd.concat([data, data_hate_final])

data_aug.to_csv(DATA_AUG_FINAL, index=False)
# Out:
# <ipython-input-3-2e435ac9d13d>:11: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data_hate = pd.read_csv(DATA_AUG, index_col=False, error_bad_lines=False)
# b'Skipping line 93: expected 2 fields, saw 6\nSkipping line 94: expected 2 fields, saw 6\nSkipping line 95: expected 2 fields, saw 6\nSkipping line 96: expected 2 fields, saw 6\nSkipping line 97: expected 2 fields, saw 6\nSkipping line 98: expected 2 fields, saw 6\nSkipping line 99: expected 2 fields, saw 5\nSkipping line 100: expected 2 fields, saw 6\nSkipping line 127: expected 2 fields, saw 7\nSkipping line 128: expected 2 fields, saw 7\nSkipping line 129: expected 2 fields, saw 4\nSkipping line 130: expected 2 fields, saw 7\nSkipping line 131: expected 2 fields, saw 7\nSkipping line 132: expected 2 fields, saw 7\nSkipping line 133: expected 2 fields, saw 7\nSkipping line 134: expected 2 fields, saw 7\nSkipping line 187: expected 2 fields, saw 3\nSkipping line 188: expected 2 fields, saw 3\nSkipping line 189: expected 2 fields, saw 3\nSkipping line 190: expected 2 fields, saw 3\nSkipping line 191: expected 2 fields, saw 3\nSkipping line 192: expected 2 fields, saw 3\nSkipping line 193: expected 2 fields, saw 3\nSkipping line 194: expected 2 fields, saw 3\nSkipping line 412: expected 2 fields, saw 3\nSkipping line 413: expected 2 fields, saw 3\nSkipping line 414: expected 2 fields, saw 3\nSkipping line 415: expected 2 fields, saw 3\nSkipping line 416: expected 2 fields, saw 3\nSkipping line 417: expected 2 fields, saw 3\nSkipping line 418: expected 2 fields, saw 3\nSkipping line 419: expected 2 fields, saw 3\nSkipping line 681: expected 2 fields, saw 6\nSkipping line 682: expected 2 fields, saw 5\nSkipping line 683: expected 2 fields, saw 6\nSkipping line 684: expected 2 fields, saw 6\nSkipping line 685: expected 2 fields, saw 5\nSkipping line 686: expected 2 fields, saw 6\nSkipping line 687: expected 2 fields, saw 6\nSkipping line 688: expected 2 fields, saw 5\nSkipping line 705: expected 2 fields, saw 3\nSkipping line 706: expected 2 fields, saw 3\nSkipping line 707: expected 2 fields, saw 3\nSkipping line 708: expected 2 fields, saw 3\nSkipping line 709: expected 2 fields, saw 3\nSkipping line 710: expected 2 fields, saw 3\nSkipping line 712: expected 2 fields, saw 3\nSkipping line 761: expected 2 fields, saw 3\nSkipping line 762: expected 2 fields, saw 3\nSkipping line 763: expected 2 fields, saw 3\nSkipping line 764: expected 2 fields, saw 3\nSkipping line 765: expected 2 fields, saw 3\nSkipping line 766: expected 2 fields, saw 3\nSkipping line 767: expected 2 fields, saw 3\nSkipping line 768: expected 2 fields, saw 3\nSkipping line 786: expected 2 fields, saw 3\nSkipping line 787: expected 2 fields, saw 3\nSkipping line 788: expected 2 fields, saw 3\nSkipping line 789: expected 2 fields, saw 3\nSkipping line 790: expected 2 fields, saw 3\nSkipping line 791: expected 2 fields, saw 3\nSkipping line 793: expected 2 fields, saw 3\nSkipping line 821: expected 2 fields, saw 3\nSkipping line 822: expected 2 fields, saw 3\nSkipping line 823: expected 2 fields, saw 3\nSkipping line 824: expected 2 fields, saw 3\nSkipping line 825: expected 2 fields, saw 3\nSkipping line 826: expected 2 fields, saw 3\nSkipping line 827: expected 2 fields, saw 3\nSkipping line 828: expected 2 fields, saw 3\nSkipping line 877: expected 2 fields, saw 3\nSkipping line 928: expected 2 fields, saw 9\nSkipping line 929: expected 2 fields, saw 9\nSkipping line 930: expected 2 fields, saw 8\nSkipping line 931: expected 2 fields, saw 9\nSkipping line 932: expected 2 fields, saw 9\nSkipping line 933: expected 2 fields, saw 8\nSkipping line 934: expected 2 fields, saw 8\nSkipping line 935: expected 2 fields, saw 9\nSkipping line 936: expected 2 fields, saw 3\nSkipping line 937: expected 2 fields, saw 3\nSkipping line 939: expected 2 fields, saw 3\nSkipping line 940: expected 2 fields, saw 3\nSkipping line 941: expected 2 fields, saw 3\nSkipping line 1022: expected 2 fields, saw 3\nSkipping line 1024: expected 2 fields, saw 3\nSkipping line 1025: expected 2 fields, saw 3\nSkipping line 1026: expected 2 fields, saw 3\nSkipping line 1027: expected 2 fields, sa ...
# <ipython-input-3-2e435ac9d13d>:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data_hate_2 = pd.read_csv(DATA_AUG_2, index_col=False, error_bad_lines=False)
# b'Skipping line 17: expected 2 fields, saw 3\nSkipping line 18: expected 2 fields, saw 3\nSkipping line 19: expected 2 fields, saw 3\nSkipping line 20: expected 2 fields, saw 3\nSkipping line 21: expected 2 fields, saw 3\nSkipping line 22: expected 2 fields, saw 3\nSkipping line 23: expected 2 fields, saw 3\nSkipping line 24: expected 2 fields, saw 3\nSkipping line 96: expected 2 fields, saw 4\nSkipping line 97: expected 2 fields, saw 4\nSkipping line 98: expected 2 fields, saw 4\nSkipping line 100: expected 2 fields, saw 4\nSkipping line 101: expected 2 fields, saw 4\nSkipping line 102: expected 2 fields, saw 4\nSkipping line 103: expected 2 fields, saw 4\nSkipping line 267: expected 2 fields, saw 4\nSkipping line 268: expected 2 fields, saw 4\nSkipping line 269: expected 2 fields, saw 4\nSkipping line 270: expected 2 fields, saw 4\nSkipping line 271: expected 2 fields, saw 4\nSkipping line 272: expected 2 fields, saw 4\nSkipping line 273: expected 2 fields, saw 4\nSkipping line 317: expected 2 fields, saw 3\nSkipping line 318: expected 2 fields, saw 3\nSkipping line 319: expected 2 fields, saw 3\nSkipping line 320: expected 2 fields, saw 3\nSkipping line 321: expected 2 fields, saw 3\nSkipping line 322: expected 2 fields, saw 3\nSkipping line 323: expected 2 fields, saw 3\nSkipping line 324: expected 2 fields, saw 3\nSkipping line 333: expected 2 fields, saw 3\nSkipping line 334: expected 2 fields, saw 3\nSkipping line 335: expected 2 fields, saw 3\nSkipping line 336: expected 2 fields, saw 3\nSkipping line 337: expected 2 fields, saw 3\nSkipping line 338: expected 2 fields, saw 3\nSkipping line 339: expected 2 fields, saw 3\nSkipping line 340: expected 2 fields, saw 3\nSkipping line 357: expected 2 fields, saw 3\nSkipping line 358: expected 2 fields, saw 3\nSkipping line 359: expected 2 fields, saw 3\nSkipping line 360: expected 2 fields, saw 3\nSkipping line 361: expected 2 fields, saw 3\nSkipping line 362: expected 2 fields, saw 3\nSkipping line 363: expected 2 fields, saw 3\nSkipping line 364: expected 2 fields, saw 3\nSkipping line 426: expected 2 fields, saw 5\nSkipping line 427: expected 2 fields, saw 5\nSkipping line 428: expected 2 fields, saw 5\nSkipping line 429: expected 2 fields, saw 5\nSkipping line 430: expected 2 fields, saw 5\nSkipping line 431: expected 2 fields, saw 5\nSkipping line 432: expected 2 fields, saw 5\nSkipping line 433: expected 2 fields, saw 5\nSkipping line 446: expected 2 fields, saw 4\nSkipping line 447: expected 2 fields, saw 4\nSkipping line 448: expected 2 fields, saw 4\nSkipping line 449: expected 2 fields, saw 4\nSkipping line 450: expected 2 fields, saw 3\nSkipping line 451: expected 2 fields, saw 4\nSkipping line 452: expected 2 fields, saw 4\nSkipping line 453: expected 2 fields, saw 4\nSkipping line 493: expected 2 fields, saw 5\nSkipping line 494: expected 2 fields, saw 5\nSkipping line 495: expected 2 fields, saw 4\nSkipping line 496: expected 2 fields, saw 4\nSkipping line 497: expected 2 fields, saw 5\nSkipping line 498: expected 2 fields, saw 5\nSkipping line 499: expected 2 fields, saw 5\nSkipping line 500: expected 2 fields, saw 5\nSkipping line 501: expected 2 fields, saw 3\nSkipping line 502: expected 2 fields, saw 3\nSkipping line 503: expected 2 fields, saw 3\nSkipping line 504: expected 2 fields, saw 3\nSkipping line 505: expected 2 fields, saw 3\nSkipping line 506: expected 2 fields, saw 3\nSkipping line 507: expected 2 fields, saw 3\nSkipping line 508: expected 2 fields, saw 3\nSkipping line 564: expected 2 fields, saw 3\nSkipping line 565: expected 2 fields, saw 3\nSkipping line 566: expected 2 fields, saw 3\nSkipping line 567: expected 2 fields, saw 3\nSkipping line 568: expected 2 fields, saw 3\nSkipping line 569: expected 2 fields, saw 3\nSkipping line 570: expected 2 fields, saw 3\nSkipping line 571: expected 2 fields, saw 3\nSkipping line 580: expected 2 fields, saw 3\nSkipping line 582: expected 2 fields, saw 3\nSkipping line 583: expected 2 fields, saw 3\nSkip ...

# %%
import pandas as pd
test = '/content/merged_file.csv'
DATA = pd.read_csv(test,index_col=False)
DATA['free_text'] = DATA['free_text'].str.replace('_', ' ')
DATA.to_csv("/content/final.csv",index=False)
